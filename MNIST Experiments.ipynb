# %% [markdown]
# ## Installing and importing libraries

# %%
# !pip install einops

# %%
import torchvision
import torch
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import einops 


import torch.optim as optim
import time
import torch.nn as nn
import torch.nn.functional as F

from sklearn.model_selection import train_test_split
from torch.utils.data import Subset

# %% [markdown]
# ## Helper Functions

# %%
import torchvision
import torch
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import einops 


import torch.optim as optim
import time
import torch.nn as nn
import torch.nn.functional as F

from sklearn.model_selection import train_test_split
from torch.utils.data import Subset

torch.set_printoptions(linewidth=120)

import torch
import torchvision
from torchvision import transforms
import matplotlib.pyplot as plt

def get_seed_images(k=1, n_classes=10):
  class_list = []
  final_classes = []
  mean = 0.1307;  std = 0.3081
  train_set = torchvision.datasets.MNIST(root="./", download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean, std)]))
  for _ in range(k):
    for i in range(n_classes):
      class_list.append(i)
  dataloader = torch.utils.data.DataLoader(train_set, batch_size=100, shuffle=True, num_workers=1)
  rand_images = torch.zeros(k * n_classes, 1, 28, 28)

  j=0
  for images, targets in dataloader:
    for i in range(images.shape[0]):
      if targets[i] in class_list:
        rand_images[j] = images[i]
        j += 1
        class_list.remove(targets[i])
        final_classes.append(targets[i].item())

        if class_list == []:
          break

  return rand_images, final_classes

def augment(device, imgs):

## position to be randomised - use mask to find object, linearly translate it, then create new mask and use that to randomise background 
## look into enlarging image dimensions from 28x28 to 40x40(potentially)
  
  mask = imgs.le(-0.8)
  random_patch = torch.rand(imgs.shape[0], 1, 28, 28).to(device)
  random_patch[mask] = imgs[mask] 

  random_grid = torch.rand(imgs.shape[0], 1, 39, 39).to(device)

  new_x = np.random.randint(0, 12)
  new_y = np.random.randint(0, 12)

  random_grid[:,:,new_x:new_x+28,new_y:new_y+28] = imgs 

  return random_grid

class Augmented_Dataset(torch.utils.data.Dataset):
  def __init__(self, images, labels):

        self.images = images
        self.labels = labels

  def __len__(self):
      return len(self.images)

  def __getitem__(self, idx):
      if torch.is_tensor(idx):
          idx = idx.tolist()

      image = self.images[idx]
      label = self.labels[idx]

      return image, label

# %% [markdown]
# ## Experiments with dataset size

# %%
dataset_sizes = [50, 100, 150, 200, 300, 400]

# %% [markdown]
# ### Modified LeNet

# %%
class Network(nn.Module): # extend nn.Module class of nn
    def __init__(self):
        super().__init__() # super class constructor
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(5,5))
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=(5,5))
        self.fc1 = nn.Linear(in_features=12*6*6, out_features=120)
        self.fc2 = nn.Linear(in_features=120, out_features=60)
        self.out = nn.Linear(in_features=60, out_features=10)
        
    def forward(self, t): # implements the forward method (flow of tensors)
        
        # hidden conv layer 
        t = self.conv1(t) 
        t = F.max_pool2d(input=t, kernel_size=2, stride=2) 
        t = F.relu(t)
        
        # hidden conv layer
        t = self.conv2(t) 
        t = F.max_pool2d(input=t, kernel_size=2, stride=2) 
        t = F.relu(t)
        
        # flatten
        t = t.reshape(-1, 12*6*6)
        t = self.fc1(t)
        t = F.relu(t)
        t = self.fc2(t)
        t = F.relu(t)
        
        # output
        t = self.out(t)
        
        return t

# %%
experiment_1_all_accuracies = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
seed_images, classes = get_seed_images(k=2) #get_seed_images().to(device)
seed_images = seed_images.to(device)
print("Seed images collected!")
for n in dataset_sizes:  
  
  accuracies = []

  for j in range(5):
    accuracy_epoch = []
    print(f"n = {n}")

    n = n                              #6000 - size of FashionMNIST
    n_classes = 10

    max_accuracy = 0

    dataset_images = torch.zeros(n*n_classes,1,39,39) 
    dataset_labels = einops.repeat(torch.tensor(classes), 'n -> (repeat n)', repeat=n//2)

    for i in range(n//2):
      new_images = augment(device, seed_images)
      dataset_images[10*2*i:10*2*i+10*2] = new_images

    dataset = Augmented_Dataset(dataset_images, dataset_labels)

    train_idx, validation_idx = train_test_split(np.arange(len(dataset)),
                                                test_size=0.1,
                                                random_state=999,
                                                shuffle=True,
                                                stratify=dataset.labels)

    train_dataset = Subset(dataset, train_idx)
    validation_dataset = Subset(dataset, validation_idx)

    cnn_model = Network().to(device) # init model

    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=90, shuffle=True, num_workers=1)
    test_dataloader = torch.utils.data.DataLoader(validation_dataset, batch_size=10, shuffle=False, num_workers=1)

    optimizer = optim.Adam(lr=0.01, params=cnn_model.parameters())
    # def train loop
    def get_item(preds, labels):
        """function that returns the accuracy of our architecture"""
        return preds.argmax(dim=1).eq(labels).sum().item()

    for epoch in range(10):
        start_time = time.time()
        total_correct = 0
        total_loss = 0
        for batch in train_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs) # get preds
            loss = F.cross_entropy(preds, lbls) # compute loss
            optimizer.zero_grad() # zero grads
            loss.backward() # calculates gradients 
            optimizer.step() # update the weights
            total_loss += loss.item()
        
        for batch in test_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs)
            total_correct += get_item(preds, lbls)
            accuracy = total_correct/len(validation_dataset)

        accuracy_epoch.append(accuracy)
        end_time = time.time() - start_time    
        print("Epoch no.",epoch+1 ,"|test accuracy: ", round(accuracy*100, 3),"%", "|total_loss: ", total_loss, "| epoch_duration: ", round(end_time,2),"sec")
    
    accuracies.append(accuracy_epoch)

  experiment_1_all_accuracies.append(accuracies)
# Out:
# Seed images collected!
# n = 50
# Epoch no. 1 |test accuracy:  16.0 % |total_loss:  11.515841722488403 | epoch_duration:  0.3 sec
# Epoch no. 2 |test accuracy:  36.0 % |total_loss:  10.349736094474792 | epoch_duration:  0.3 sec
# Epoch no. 3 |test accuracy:  52.0 % |total_loss:  7.8726115226745605 | epoch_duration:  0.3 sec
# Epoch no. 4 |test accuracy:  58.0 % |total_loss:  6.463147163391113 | epoch_duration:  0.3 sec
# Epoch no. 5 |test accuracy:  72.0 % |total_loss:  4.097517490386963 | epoch_duration:  0.3 sec
# Epoch no. 6 |test accuracy:  88.0 % |total_loss:  1.763671800494194 | epoch_duration:  0.3 sec
# Epoch no. 7 |test accuracy:  84.0 % |total_loss:  0.9857658594846725 | epoch_duration:  0.3 sec
# Epoch no. 8 |test accuracy:  92.0 % |total_loss:  0.5071555152535439 | epoch_duration:  0.29 sec
# Epoch no. 9 |test accuracy:  90.0 % |total_loss:  0.30096230935305357 | epoch_duration:  0.28 sec
# Epoch no. 10 |test accuracy:  88.0 % |total_loss:  0.2909429296851158 | epoch_duration:  0.31 sec
# n = 50
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  11.781332015991211 | epoch_duration:  0.3 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  11.530498743057251 | epoch_duration:  0.29 sec
# Epoch no. 3 |test accuracy:  10.0 % |total_loss:  11.525294065475464 | epoch_duration:  0.28 sec
# Epoch no. 4 |test accuracy:  10.0 % |total_loss:  11.521126508712769 | epoch_duration:  0.29 sec
# Epoch no. 5 |test accuracy:  10.0 % |total_loss:  11.517831563949585 | epoch_duration:  0.29 sec
# Epoch no. 6 |test accuracy:  10.0 % |total_loss:  11.517327547073364 | epoch_duration:  0.28 sec
# Epoch no. 7 |test accuracy:  10.0 % |total_loss:  11.516895294189453 | epoch_duration:  0.29 sec
# Epoch no. 8 |test accuracy:  16.0 % |total_loss:  11.514594078063965 | epoch_duration:  0.3 sec
# Epoch no. 9 |test accuracy:  10.0 % |total_loss:  11.462691068649292 | epoch_duration:  0.29 sec
# Epoch no. 10 |test accuracy:  16.0 % |total_loss:  11.031514644622803 | epoch_duration:  0.29 sec
# n = 50
# Epoch no. 1 |test accuracy:  16.0 % |total_loss:  11.60216236114502 | epoch_duration:  0.29 sec
# Epoch no. 2 |test accuracy:  12.0 % |total_loss:  11.372478485107422 | epoch_duration:  0.3 sec
# Epoch no. 3 |test accuracy:  16.0 % |total_loss:  10.546679496765137 | epoch_duration:  0.4 sec
# Epoch no. 4 |test accuracy:  40.0 % |total_loss:  9.3077632188797 | epoch_duration:  0.45 sec
# Epoch no. 5 |test accuracy:  54.0 % |total_loss:  7.662630558013916 | epoch_duration:  0.44 sec
# Epoch no. 6 |test accuracy:  62.0 % |total_loss:  5.911346673965454 | epoch_duration:  0.45 sec
# Epoch no. 7 |test accuracy:  58.0 % |total_loss:  4.068358540534973 | epoch_duration:  0.45 sec
# Epoch no. 8 |test accuracy:  70.0 % |total_loss:  2.6252050697803497 | epoch_duration:  0.46 sec
# Epoch no. 9 |test accuracy:  78.0 % |total_loss:  2.0103053748607635 | epoch_duration:  0.32 sec
# Epoch no. 10 |test accuracy:  76.0 % |total_loss:  1.4562400877475739 | epoch_duration:  0.28 sec
# n = 50
# Epoch no. 1 |test accuracy:  16.0 % |total_loss:  11.556246280670166 | epoch_duration:  0.29 sec
# Epoch no. 2 |test accuracy:  26.0 % |total_loss:  11.275552988052368 | epoch_duration:  0.3 sec
# Epoch no. 3 |test accuracy:  38.0 % |total_loss:  9.551896810531616 | epoch_duration:  0.28 sec
# Epoch no. 4 |test accuracy:  46.0 % |total_loss:  7.047803044319153 | epoch_duration:  0.3 sec
# Epoch no. 5 |test accuracy:  72.0 % |total_loss:  4.9925971031188965 | epoch_duration:  0.3 sec
# Epoch no. 6 |test accuracy:  72.0 % |total_loss:  3.0976849496364594 | epoch_duration:  0.29 sec
# Epoch no. 7 |test accuracy:  86.0 % |total_loss:  1.50515878200531 | epoch_duration:  0.3 sec
# Epoch no. 8 |test accuracy:  86.0 % |total_loss:  0.531244769692421 | epoch_duration:  0.3 sec
# Epoch no. 9 |test accuracy:  96.0 % |total_loss:  0.5948157049715519 | epoch_duration:  0.3 sec
# Epoch no. 10 |test accuracy:  88.0 % |total_loss:  0.4619656540453434 | epoch_duration:  0.29 sec
# n = 50
# Epoch no. 1 |test accuracy:  16.0 % |total_loss:  11.577397584915161 | epoch_duration:  0.29 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  11.364591836929321 | epoch_duration:  0.29 sec
# Epoch no. 3 |test accuracy:  10.0 % |total_loss:  10.84734058380127 | epoch_duration:  0.29 sec
# Epoch no. 4 |test accuracy:  38.0 % |total_loss:  9.646920919418335 | epoch_duration:  0.3 sec
# Epoch no. 5 |test accuracy:  48.0 % |total_loss:  7.941442966461182 | epoch_duration:  0.31 sec
# Epoch no. 6 |test accuracy:  70.0 % |total_loss:  5.876408219337463 | epoch_duration:  0.31 sec
# Epoch no. 7 |test accuracy:  78.0 % |total_loss:  3.615483582019806 | epoch_duration:  0.29 sec
# Epoch no. 8 |test accuracy:  94.0 % |total_loss:  2.061907947063446 | epoch_duration:  0.3 sec
# Epoch no. 9 |test accuracy:  98.0 % |total_loss:  1.1978348344564438 | epoch_duration:  0.29 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.5272657796740532 | epoch_duration:  0.29 sec
# n = 100
# Epoch no. 1 |test accuracy:  14.0 % |total_loss:  22.877493143081665 | epoch_duration:  0.46 sec
# Epoch no. 2 |test accuracy:  42.0 % |total_loss:  20.526987075805664 | epoch_duration:  0.46 sec
# Epoch no. 3 |test accuracy:  63.0 % |total_loss:  14.118899583816528 | epoch_duration:  0.45 sec
# Epoch no. 4 |test accuracy:  77.0 % |total_loss:  8.138793587684631 | epoch_duration:  0.45 sec
# Epoch no. 5 |test accuracy:  83.0 % |total_loss:  6.761588841676712 | epoch_duration:  0.45 sec
# Epoch no. 6 |test accuracy:  83.0 % |total_loss:  3.482200503349304 | epoch_duration:  0.45 sec
# Epoch no. 7 |test accuracy:  98.0 % |total_loss:  1.5812378376722336 | epoch_duration:  0.46 sec
# Epoch no. 8 |test accuracy:  99.0 % |total_loss:  0.4817666783928871 | epoch_duration:  0.56 sec
# Epoch no. 9 |test accuracy:  99.0 % |total_loss:  0.14246432669460773 | epoch_duration:  0.71 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  0.08454189612530172 | epoch_duration:  0.73 sec
# n = 100
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  23.137223720550537 | epoch_duration:  0.7 sec
# Epoch no. 2 |test accuracy:  19.0 % |total_loss:  21.66083300113678 | epoch_duration:  0.5 sec
# Epoch no. 3 |test accuracy:  31.0 % |total_loss:  17.417668342590332 | epoch_duration:  0.45 sec
# Epoch no. 4 |test accuracy:  58.0 % |total_loss:  13.091402769088745 | epoch_duration:  0.44 sec
# Epoch no. 5 |test accuracy:  71.0 % |total_loss:  9.825481474399567 | epoch_duration:  0.46 sec
# Epoch no. 6 |test accuracy:  92.0 % |total_loss:  6.689150154590607 | epoch_duration:  0.44 sec
# Epoch no. 7 |test accuracy:  98.0 % |total_loss:  4.16811802983284 | epoch_duration:  0.47 sec
# Epoch no. 8 |test accuracy:  96.0 % |total_loss:  2.2951290160417557 | epoch_duration:  0.45 sec
# Epoch no. 9 |test accuracy:  98.0 % |total_loss:  1.2127035409212112 | epoch_duration:  0.46 sec
# Epoch no. 10 |test accuracy:  97.0 % |total_loss:  0.5484392885118723 | epoch_duration:  0.43 sec
# n = 100
# Epoch no. 1 |test accuracy:  30.0 % |total_loss:  22.780999302864075 | epoch_duration:  0.46 sec
# Epoch no. 2 |test accuracy:  40.0 % |total_loss:  18.901310443878174 | epoch_duration:  0.45 sec
# Epoch no. 3 |test accuracy:  66.0 % |total_loss:  11.734261572360992 | epoch_duration:  0.44 sec
# Epoch no. 4 |test accuracy:  77.0 % |total_loss:  7.664763420820236 | epoch_duration:  0.45 sec
# Epoch no. 5 |test accuracy:  94.0 % |total_loss:  3.9536116421222687 | epoch_duration:  0.45 sec
# Epoch no. 6 |test accuracy:  96.0 % |total_loss:  1.6877753771841526 | epoch_duration:  0.46 sec
# Epoch no. 7 |test accuracy:  95.0 % |total_loss:  1.182804461568594 | epoch_duration:  0.45 sec
# Epoch no. 8 |test accuracy:  97.0 % |total_loss:  1.2073053661733866 | epoch_duration:  0.46 sec
# Epoch no. 9 |test accuracy:  98.0 % |total_loss:  0.6780535001307726 | epoch_duration:  0.46 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  0.23908332083374262 | epoch_duration:  0.46 sec
# n = 100
# Epoch no. 1 |test accuracy:  13.0 % |total_loss:  22.79446029663086 | epoch_duration:  0.47 sec
# Epoch no. 2 |test accuracy:  63.0 % |total_loss:  17.509193420410156 | epoch_duration:  0.46 sec
# Epoch no. 3 |test accuracy:  80.0 % |total_loss:  7.56152731180191 | epoch_duration:  0.45 sec
# Epoch no. 4 |test accuracy:  92.0 % |total_loss:  2.861222006380558 | epoch_duration:  0.72 sec
# Epoch no. 5 |test accuracy:  94.0 % |total_loss:  1.3172944448888302 | epoch_duration:  0.72 sec
# Epoch no. 6 |test accuracy:  95.0 % |total_loss:  1.4262593584135175 | epoch_duration:  0.73 sec
# Epoch no. 7 |test accuracy:  97.0 % |total_loss:  0.7417020332068205 | epoch_duration:  0.63 sec
# Epoch no. 8 |test accuracy:  96.0 % |total_loss:  0.23342181462794542 | epoch_duration:  0.45 sec
# Epoch no. 9 |test accuracy:  97.0 % |total_loss:  0.0731219481676817 | epoch_duration:  0.46 sec
# Epoch no. 10 |test accuracy:  97.0 % |total_loss:  0.03715291031403467 | epoch_duration:  0.45 sec
# n = 100
# Epoch no. 1 |test accuracy:  24.0 % |total_loss:  22.761593341827393 | epoch_duration:  0.44 sec
# Epoch no. 2 |test accuracy:  62.0 % |total_loss:  17.677200198173523 | epoch_duration:  0.45 sec
# Epoch no. 3 |test accuracy:  75.0 % |total_loss:  10.267382621765137 | epoch_duration:  0.45 sec
# Epoch no. 4 |test accuracy:  87.0 % |total_loss:  4.52167621254921 | epoch_duration:  0.48 sec
# Epoch no. 5 |test accuracy:  88.0 % |total_loss:  1.3669851869344711 | epoch_duration:  0.48 sec
# Epoch no. 6 |test accuracy:  97.0 % |total_loss:  1.2931790314614773 | epoch_duration:  0.46 sec
# Epoch no. 7 |test accuracy:  97.0 % |total_loss:  0.4788189474493265 | epoch_duration:  0.45 sec
# Epoch no. 8 |test accuracy:  99.0 % |total_loss:  0.2250013668090105 | epoch_duration:  0.45 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.05942374817095697 | epoch_duration:  0.46 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  0.026352507527917624 | epoch_duration:  0.46 sec
# n = 150
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  34.640968799591064 | epoch_duration:  0.61 sec
# Epoch no. 2 |test accuracy:  32.667 % |total_loss:  32.46913492679596 | epoch_duration:  0.61 sec
# Epoch no. 3 |test accuracy:  49.333 % |total_loss:  25.228397846221924 | epoch_duration:  0.61 sec
# Epoch no. 4 |test accuracy:  77.333 % |total_loss:  13.814815938472748 | epoch_duration:  0.61 sec
# Epoch no. 5 |test accuracy:  89.333 % |total_loss:  6.6258814334869385 | epoch_duration:  0.59 sec
# Epoch no. 6 |test accuracy:  92.667 % |total_loss:  6.650477305054665 | epoch_duration:  0.62 sec
# Epoch no. 7 |test accuracy:  96.667 % |total_loss:  3.764867141842842 | epoch_duration:  0.84 sec
# Epoch no. 8 |test accuracy:  97.333 % |total_loss:  1.8914657607674599 | epoch_duration:  0.98 sec
# Epoch no. 9 |test accuracy:  95.333 % |total_loss:  1.5654124729335308 | epoch_duration:  1.0 sec
# Epoch no. 10 |test accuracy:  94.667 % |total_loss:  1.4976812228560448 | epoch_duration:  0.61 sec
# n = 150
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  34.72003889083862 | epoch_duration:  0.62 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  34.5617151260376 | epoch_duration:  0.6 sec
# Epoch no. 3 |test accuracy:  10.0 % |total_loss:  34.55892825126648 | epoch_duration:  0.6 sec
# Epoch no. 4 |test accuracy:  10.0 % |total_loss:  34.559343576431274 | epoch_duration:  0.61 sec
# Epoch no. 5 |test accuracy:  10.0 % |total_loss:  34.549503326416016 | epoch_duration:  0.6 sec
# Epoch no. 6 |test accuracy:  10.0 % |total_loss:  34.55390477180481 | epoch_duration:  0.62 sec
# Epoch no. 7 |test accuracy:  10.0 % |total_loss:  34.55050849914551 | epoch_duration:  0.61 sec
# Epoch no. 8 |test accuracy:  10.0 % |total_loss:  34.546669006347656 | epoch_duration:  0.59 sec
# Epoch no. 9 |test accuracy:  10.0 % |total_loss:  34.559887409210205 | epoch_duration:  0.61 sec
# Epoch no. 10 |test accuracy:  10.0 % |total_loss:  34.550208568573 | epoch_duration:  0.63 sec
# n = 150
# Epoch no. 1 |test accuracy:  14.667 % |total_loss:  34.65989065170288 | epoch_duration:  0.62 sec
# Epoch no. 2 |test accuracy:  27.333 % |total_loss:  31.82943093776703 | epoch_duration:  0.6 sec
# Epoch no. 3 |test accuracy:  52.0 % |total_loss:  22.87833273410797 | epoch_duration:  0.61 sec
# Epoch no. 4 |test accuracy:  68.667 % |total_loss:  13.536974251270294 | epoch_duration:  0.64 sec
# Epoch no. 5 |test accuracy:  80.0 % |total_loss:  7.927498698234558 | epoch_duration:  0.6 sec
# Epoch no. 6 |test accuracy:  88.0 % |total_loss:  4.9878222942352295 | epoch_duration:  0.89 sec
# Epoch no. 7 |test accuracy:  88.667 % |total_loss:  3.303016409277916 | epoch_duration:  0.99 sec
# Epoch no. 8 |test accuracy:  96.667 % |total_loss:  1.7239783629775047 | epoch_duration:  0.95 sec
# Epoch no. 9 |test accuracy:  93.333 % |total_loss:  1.783076111227274 | epoch_duration:  0.61 sec
# Epoch no. 10 |test accuracy:  90.667 % |total_loss:  1.747426800429821 | epoch_duration:  0.6 sec
# n = 150
# Epoch no. 1 |test accuracy:  32.0 % |total_loss:  32.7063125371933 | epoch_duration:  0.61 sec
# Epoch no. 2 |test accuracy:  68.0 % |total_loss:  18.95560747385025 | epoch_duration:  0.61 sec
# Epoch no. 3 |test accuracy:  95.333 % |total_loss:  4.6770971566438675 | epoch_duration:  0.63 sec
# Epoch no. 4 |test accuracy:  97.333 % |total_loss:  0.966769615188241 | epoch_duration:  0.61 sec
# Epoch no. 5 |test accuracy:  98.0 % |total_loss:  0.39110090723261237 | epoch_duration:  0.59 sec
# Epoch no. 6 |test accuracy:  96.667 % |total_loss:  0.23781363118905574 | epoch_duration:  0.63 sec
# Epoch no. 7 |test accuracy:  98.0 % |total_loss:  0.4001887385966256 | epoch_duration:  0.64 sec
# Epoch no. 8 |test accuracy:  98.0 % |total_loss:  0.5432124370709062 | epoch_duration:  0.6 sec
# Epoch no. 9 |test accuracy:  96.667 % |total_loss:  0.44703253312036395 | epoch_duration:  0.62 sec
# Epoch no. 10 |test accuracy:  96.667 % |total_loss:  0.4705678967293352 | epoch_duration:  0.63 sec
# n = 150
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  34.55575203895569 | epoch_duration:  0.61 sec
# Epoch no. 2 |test accuracy:  24.667 % |total_loss:  32.67959141731262 | epoch_duration:  0.6 sec
# Epoch no. 3 |test accuracy:  34.0 % |total_loss:  28.555009245872498 | epoch_duration:  0.59 sec
# Epoch no. 4 |test accuracy:  50.667 % |total_loss:  20.606211066246033 | epoch_duration:  0.64 sec
# Epoch no. 5 |test accuracy:  72.667 % |total_loss:  11.846054017543793 | epoch_duration:  0.98 sec
# Epoch no. 6 |test accuracy:  87.333 % |total_loss:  5.586686208844185 | epoch_duration:  0.98 sec
# Epoch no. 7 |test accuracy:  94.667 % |total_loss:  2.0641691982746124 | epoch_duration:  0.91 sec
# Epoch no. 8 |test accuracy:  94.0 % |total_loss:  0.8861497323960066 | epoch_duration:  0.6 sec
# Epoch no. 9 |test accuracy:  98.667 % |total_loss:  0.5370957348495722 | epoch_duration:  0.6 sec
# Epoch no. 10 |test accuracy:  98.667 % |total_loss:  0.19058108422905207 | epoch_duration:  0.61 sec
# n = 200
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  46.27492880821228 | epoch_duration:  0.75 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  46.087923526763916 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  20.0 % |total_loss:  45.97873497009277 | epoch_duration:  0.76 sec
# Epoch no. 4 |test accuracy:  28.0 % |total_loss:  41.29371917247772 | epoch_duration:  0.75 sec
# Epoch no. 5 |test accuracy:  32.5 % |total_loss:  36.41069972515106 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  37.0 % |total_loss:  33.42345058917999 | epoch_duration:  0.76 sec
# Epoch no. 7 |test accuracy:  39.0 % |total_loss:  30.407704710960388 | epoch_duration:  0.74 sec
# Epoch no. 8 |test accuracy:  39.5 % |total_loss:  29.03398311138153 | epoch_duration:  0.75 sec
# Epoch no. 9 |test accuracy:  44.0 % |total_loss:  27.967724800109863 | epoch_duration:  0.75 sec
# Epoch no. 10 |test accuracy:  43.5 % |total_loss:  26.992401123046875 | epoch_duration:  0.76 sec
# n = 200
# Epoch no. 1 |test accuracy:  29.0 % |total_loss:  42.60127055644989 | epoch_duration:  0.99 sec
# Epoch no. 2 |test accuracy:  75.5 % |total_loss:  25.457994401454926 | epoch_duration:  1.26 sec
# Epoch no. 3 |test accuracy:  84.0 % |total_loss:  6.326904363930225 | epoch_duration:  1.07 sec
# Epoch no. 4 |test accuracy:  97.5 % |total_loss:  6.138816498219967 | epoch_duration:  0.76 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.8576556965708733 | epoch_duration:  0.76 sec
# Epoch no. 6 |test accuracy:  99.5 % |total_loss:  0.09019328647991642 | epoch_duration:  0.76 sec
# Epoch no. 7 |test accuracy:  99.5 % |total_loss:  0.020810591406188905 | epoch_duration:  0.77 sec
# Epoch no. 8 |test accuracy:  99.5 % |total_loss:  0.007531397088314407 | epoch_duration:  0.77 sec
# Epoch no. 9 |test accuracy:  99.5 % |total_loss:  0.005078031470475253 | epoch_duration:  0.76 sec
# Epoch no. 10 |test accuracy:  99.5 % |total_loss:  0.004074694617884234 | epoch_duration:  0.76 sec
# n = 200
# Epoch no. 1 |test accuracy:  36.0 % |total_loss:  40.92363178730011 | epoch_duration:  0.77 sec
# Epoch no. 2 |test accuracy:  88.0 % |total_loss:  18.972487717866898 | epoch_duration:  0.79 sec
# Epoch no. 3 |test accuracy:  92.0 % |total_loss:  5.374307535588741 | epoch_duration:  0.79 sec
# Epoch no. 4 |test accuracy:  97.5 % |total_loss:  2.103051306679845 | epoch_duration:  0.77 sec
# Epoch no. 5 |test accuracy:  99.5 % |total_loss:  0.4980357699096203 | epoch_duration:  0.77 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.25825372186955065 | epoch_duration:  0.95 sec
# Epoch no. 7 |test accuracy:  98.5 % |total_loss:  0.13638982304837555 | epoch_duration:  1.25 sec
# Epoch no. 8 |test accuracy:  99.0 % |total_loss:  0.07642506723641418 | epoch_duration:  1.12 sec
# Epoch no. 9 |test accuracy:  99.0 % |total_loss:  0.013185448842705227 | epoch_duration:  0.8 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.013266180001664907 | epoch_duration:  0.82 sec
# n = 200
# Epoch no. 1 |test accuracy:  30.0 % |total_loss:  45.52313494682312 | epoch_duration:  0.8 sec
# Epoch no. 2 |test accuracy:  58.0 % |total_loss:  30.87079894542694 | epoch_duration:  0.8 sec
# Epoch no. 3 |test accuracy:  85.5 % |total_loss:  14.027940958738327 | epoch_duration:  0.73 sec
# Epoch no. 4 |test accuracy:  74.5 % |total_loss:  6.20911405980587 | epoch_duration:  0.76 sec
# Epoch no. 5 |test accuracy:  96.0 % |total_loss:  4.713641241192818 | epoch_duration:  0.78 sec
# Epoch no. 6 |test accuracy:  96.5 % |total_loss:  1.5810081362724304 | epoch_duration:  0.79 sec
# Epoch no. 7 |test accuracy:  98.5 % |total_loss:  0.7055636532604694 | epoch_duration:  0.8 sec
# Epoch no. 8 |test accuracy:  99.5 % |total_loss:  0.3896225751377642 | epoch_duration:  0.76 sec
# Epoch no. 9 |test accuracy:  99.5 % |total_loss:  0.1655748711200431 | epoch_duration:  0.76 sec
# Epoch no. 10 |test accuracy:  99.5 % |total_loss:  0.08057865017326549 | epoch_duration:  0.79 sec
# n = 200
# Epoch no. 1 |test accuracy:  39.5 % |total_loss:  40.98696970939636 | epoch_duration:  1.14 sec
# Epoch no. 2 |test accuracy:  87.0 % |total_loss:  18.695997893810272 | epoch_duration:  1.24 sec
# Epoch no. 3 |test accuracy:  89.5 % |total_loss:  6.422116287052631 | epoch_duration:  0.99 sec
# Epoch no. 4 |test accuracy:  97.0 % |total_loss:  4.458269439637661 | epoch_duration:  0.79 sec
# Epoch no. 5 |test accuracy:  99.5 % |total_loss:  1.3249386763200164 | epoch_duration:  0.77 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.2410230403766036 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  98.5 % |total_loss:  0.16853294195607305 | epoch_duration:  0.79 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.16365687065990642 | epoch_duration:  0.79 sec
# Epoch no. 9 |test accuracy:  97.5 % |total_loss:  0.25838253425899893 | epoch_duration:  0.76 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.151001386315329 | epoch_duration:  0.74 sec
# n = 300
# Epoch no. 1 |test accuracy:  45.0 % |total_loss:  59.92989432811737 | epoch_duration:  1.1 sec
# Epoch no. 2 |test accuracy:  66.333 % |total_loss:  30.326981782913208 | epoch_duration:  1.08 sec
# Epoch no. 3 |test accuracy:  85.333 % |total_loss:  16.17429083585739 | epoch_duration:  1.07 sec
# Epoch no. 4 |test accuracy:  93.0 % |total_loss:  7.716572567820549 | epoch_duration:  1.19 sec
# Epoch no. 5 |test accuracy:  95.333 % |total_loss:  3.6369197964668274 | epoch_duration:  1.82 sec
# Epoch no. 6 |test accuracy:  93.333 % |total_loss:  5.742053501307964 | epoch_duration:  1.25 sec
# Epoch no. 7 |test accuracy:  95.333 % |total_loss:  3.7197123989462852 | epoch_duration:  1.07 sec
# Epoch no. 8 |test accuracy:  97.333 % |total_loss:  0.8548888964578509 | epoch_duration:  1.08 sec
# Epoch no. 9 |test accuracy:  99.0 % |total_loss:  0.3749471865594387 | epoch_duration:  1.09 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  0.11838880309369415 | epoch_duration:  1.08 sec
# n = 300
# Epoch no. 1 |test accuracy:  42.667 % |total_loss:  65.10106921195984 | epoch_duration:  1.1 sec
# Epoch no. 2 |test accuracy:  87.667 % |total_loss:  26.717322319746017 | epoch_duration:  1.08 sec
# Epoch no. 3 |test accuracy:  98.333 % |total_loss:  6.0232455767691135 | epoch_duration:  1.09 sec
# Epoch no. 4 |test accuracy:  99.667 % |total_loss:  0.9662663745693862 | epoch_duration:  1.09 sec
# Epoch no. 5 |test accuracy:  99.667 % |total_loss:  0.7703733542002738 | epoch_duration:  1.51 sec
# Epoch no. 6 |test accuracy:  99.333 % |total_loss:  0.6534294891171157 | epoch_duration:  1.73 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.16573601483833045 | epoch_duration:  1.09 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.01862626546062529 | epoch_duration:  1.07 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.003352366438775789 | epoch_duration:  1.1 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0024732792226132005 | epoch_duration:  1.1 sec
# n = 300
# Epoch no. 1 |test accuracy:  60.0 % |total_loss:  49.37138319015503 | epoch_duration:  1.1 sec
# Epoch no. 2 |test accuracy:  97.667 % |total_loss:  7.096184276044369 | epoch_duration:  1.07 sec
# Epoch no. 3 |test accuracy:  96.0 % |total_loss:  2.2207119949162006 | epoch_duration:  1.08 sec
# Epoch no. 4 |test accuracy:  98.333 % |total_loss:  1.6147434059530497 | epoch_duration:  1.07 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.9609823061618954 | epoch_duration:  1.1 sec
# Epoch no. 6 |test accuracy:  99.333 % |total_loss:  0.3311914063524455 | epoch_duration:  1.77 sec
# Epoch no. 7 |test accuracy:  99.333 % |total_loss:  0.4301104170153849 | epoch_duration:  1.49 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.3349584635870997 | epoch_duration:  1.1 sec
# Epoch no. 9 |test accuracy:  99.667 % |total_loss:  0.3201480064308271 | epoch_duration:  1.07 sec
# Epoch no. 10 |test accuracy:  89.0 % |total_loss:  9.587852532407851 | epoch_duration:  1.08 sec
# n = 300
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  69.31916666030884 | epoch_duration:  1.08 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  69.1097559928894 | epoch_duration:  1.08 sec
# Epoch no. 3 |test accuracy:  17.333 % |total_loss:  69.20999550819397 | epoch_duration:  1.12 sec
# Epoch no. 4 |test accuracy:  10.0 % |total_loss:  69.01401877403259 | epoch_duration:  1.06 sec
# Epoch no. 5 |test accuracy:  19.0 % |total_loss:  68.50095462799072 | epoch_duration:  1.06 sec
# Epoch no. 6 |test accuracy:  76.667 % |total_loss:  42.255107045173645 | epoch_duration:  1.25 sec
# Epoch no. 7 |test accuracy:  95.0 % |total_loss:  12.26725658774376 | epoch_duration:  1.82 sec
# Epoch no. 8 |test accuracy:  99.667 % |total_loss:  2.4002393931150436 | epoch_duration:  1.24 sec
# Epoch no. 9 |test accuracy:  99.667 % |total_loss:  1.4542550458572805 | epoch_duration:  1.06 sec
# Epoch no. 10 |test accuracy:  99.333 % |total_loss:  1.1693893088959157 | epoch_duration:  1.06 sec
# n = 300
# Epoch no. 1 |test accuracy:  62.0 % |total_loss:  57.63488245010376 | epoch_duration:  1.08 sec
# Epoch no. 2 |test accuracy:  93.667 % |total_loss:  17.284121334552765 | epoch_duration:  1.06 sec
# Epoch no. 3 |test accuracy:  92.667 % |total_loss:  2.424922686070204 | epoch_duration:  1.08 sec
# Epoch no. 4 |test accuracy:  99.0 % |total_loss:  4.987615257501602 | epoch_duration:  1.08 sec
# Epoch no. 5 |test accuracy:  99.667 % |total_loss:  0.4912081711227074 | epoch_duration:  1.09 sec
# Epoch no. 6 |test accuracy:  99.667 % |total_loss:  0.22609717794694006 | epoch_duration:  1.06 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.07225852683768608 | epoch_duration:  1.48 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.07685231967479922 | epoch_duration:  1.78 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.03429858019808307 | epoch_duration:  1.08 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.006056466092559276 | epoch_duration:  1.09 sec
# n = 400
# Epoch no. 1 |test accuracy:  86.5 % |total_loss:  57.420055598020554 | epoch_duration:  1.43 sec
# Epoch no. 2 |test accuracy:  98.5 % |total_loss:  8.650878321379423 | epoch_duration:  1.41 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  0.36528895390802063 | epoch_duration:  1.38 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.02334505554608768 | epoch_duration:  1.39 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.007525531007559039 | epoch_duration:  1.41 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.004151700431975769 | epoch_duration:  1.88 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.0030403179007407743 | epoch_duration:  1.96 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.0023947277113620657 | epoch_duration:  1.39 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0019449488772806944 | epoch_duration:  1.38 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.001666908980041626 | epoch_duration:  1.37 sec
# n = 400
# Epoch no. 1 |test accuracy:  36.5 % |total_loss:  85.2171186208725 | epoch_duration:  1.4 sec
# Epoch no. 2 |test accuracy:  85.0 % |total_loss:  35.442994117736816 | epoch_duration:  1.36 sec
# Epoch no. 3 |test accuracy:  97.25 % |total_loss:  10.67470883578062 | epoch_duration:  1.4 sec
# Epoch no. 4 |test accuracy:  99.75 % |total_loss:  2.9472855012863874 | epoch_duration:  1.54 sec
# Epoch no. 5 |test accuracy:  96.75 % |total_loss:  5.174907246604562 | epoch_duration:  2.27 sec
# Epoch no. 6 |test accuracy:  99.25 % |total_loss:  1.5199959110468626 | epoch_duration:  1.37 sec
# Epoch no. 7 |test accuracy:  99.25 % |total_loss:  0.5973858393263072 | epoch_duration:  1.38 sec
# Epoch no. 8 |test accuracy:  98.75 % |total_loss:  1.084959909087047 | epoch_duration:  1.36 sec
# Epoch no. 9 |test accuracy:  97.75 % |total_loss:  3.051365854451433 | epoch_duration:  1.42 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  1.1792775238864124 | epoch_duration:  1.38 sec
# n = 400
# Epoch no. 1 |test accuracy:  38.25 % |total_loss:  88.05094814300537 | epoch_duration:  1.38 sec
# Epoch no. 2 |test accuracy:  68.0 % |total_loss:  50.65184038877487 | epoch_duration:  1.4 sec
# Epoch no. 3 |test accuracy:  86.0 % |total_loss:  21.425410091876984 | epoch_duration:  2.23 sec
# Epoch no. 4 |test accuracy:  94.0 % |total_loss:  8.583006463944912 | epoch_duration:  1.66 sec
# Epoch no. 5 |test accuracy:  91.5 % |total_loss:  8.822908487170935 | epoch_duration:  1.39 sec
# Epoch no. 6 |test accuracy:  93.0 % |total_loss:  7.658908165991306 | epoch_duration:  1.44 sec
# Epoch no. 7 |test accuracy:  95.75 % |total_loss:  3.3272008784115314 | epoch_duration:  1.37 sec
# Epoch no. 8 |test accuracy:  97.75 % |total_loss:  3.1228505298495293 | epoch_duration:  1.38 sec
# Epoch no. 9 |test accuracy:  97.0 % |total_loss:  2.477579035796225 | epoch_duration:  1.4 sec
# Epoch no. 10 |test accuracy:  96.5 % |total_loss:  2.7610990665853024 | epoch_duration:  1.37 sec
# n = 400
# Epoch no. 1 |test accuracy:  73.0 % |total_loss:  72.83832013607025 | epoch_duration:  1.97 sec
# Epoch no. 2 |test accuracy:  98.0 % |total_loss:  10.037988364696503 | epoch_duration:  1.92 sec
# Epoch no. 3 |test accuracy:  99.25 % |total_loss:  1.592866257764399 | epoch_duration:  1.36 sec
# Epoch no. 4 |test accuracy:  92.5 % |total_loss:  6.544219217263162 | epoch_duration:  1.43 sec
# Epoch no. 5 |test accuracy:  99.5 % |total_loss:  2.36572996142786 | epoch_duration:  1.38 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.22018154219404096 | epoch_duration:  1.37 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.012038248984026723 | epoch_duration:  1.37 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.006446118150051916 | epoch_duration:  1.76 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0040637544298078865 | epoch_duration:  3.43 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0032859669317986118 | epoch_duration:  1.53 sec
# n = 400
# Epoch no. 1 |test accuracy:  59.5 % |total_loss:  73.40001499652863 | epoch_duration:  1.42 sec
# Epoch no. 2 |test accuracy:  89.75 % |total_loss:  20.866986200213432 | epoch_duration:  1.39 sec
# Epoch no. 3 |test accuracy:  98.25 % |total_loss:  6.713702041655779 | epoch_duration:  1.39 sec
# Epoch no. 4 |test accuracy:  98.5 % |total_loss:  3.110245327465236 | epoch_duration:  1.38 sec
# Epoch no. 5 |test accuracy:  99.75 % |total_loss:  1.1621820990694687 | epoch_duration:  1.38 sec
# Epoch no. 6 |test accuracy:  93.75 % |total_loss:  2.5578195727430284 | epoch_duration:  1.37 sec
# Epoch no. 7 |test accuracy:  97.5 % |total_loss:  4.472324686124921 | epoch_duration:  2.1 sec
# Epoch no. 8 |test accuracy:  98.5 % |total_loss:  1.8995815420057625 | epoch_duration:  1.78 sec
# Epoch no. 9 |test accuracy:  99.25 % |total_loss:  0.874893810309004 | epoch_duration:  1.41 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.6815253377426416 | epoch_duration:  1.4 sec

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

epochs = [i for i in range(10)]
 
for i in range(len(dataset_sizes)):
  plt.plot(epochs, np.mean(np.asarray(experiment_1_all_accuracies)[i,:,:], axis=0), label=str(dataset_sizes[i]*10))

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("MNIST - Modified LeNet")
plt.legend(title="Dataset size")

# %% [markdown]
# ### Simple Convnet

# %%
class Network(nn.Module): # extend nn.Module class of nn
    def __init__(self):
        super().__init__() # super class constructor
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(5,5))
        self.fc = nn.Linear(in_features=6*35*35, out_features=10)
        
    def forward(self, t): # implements the forward method (flow of tensors)
        
        # hidden conv layer 
        t = self.conv1(t) 
        t = F.relu(t)
        
        t = t.reshape(-1, 6*35*35)
        t = self.fc(t)
        
        return t

# %%
experiment_2_all_accuracies = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
seed_images, classes = get_seed_images(k=2) #get_seed_images().to(device)
seed_images = seed_images.to(device)
print("Seed images collected!")
for n in dataset_sizes:  
  
  accuracies = []

  for j in range(5):
    accuracy_epoch = []
    print(f"n = {n}")

    n = n                              #6000 - size of FashionMNIST
    n_classes = 10

    max_accuracy = 0

    dataset_images = torch.zeros(n*n_classes,1,39,39) 
    dataset_labels = einops.repeat(torch.tensor(classes), 'n -> (repeat n)', repeat=n//2)

    for i in range(n//2):
      new_images = augment(device, seed_images)
      dataset_images[10*2*i:10*2*i+10*2] = new_images

    dataset = Augmented_Dataset(dataset_images, dataset_labels)

    train_idx, validation_idx = train_test_split(np.arange(len(dataset)),
                                                test_size=0.1,
                                                random_state=999,
                                                shuffle=True,
                                                stratify=dataset.labels)

    train_dataset = Subset(dataset, train_idx)
    validation_dataset = Subset(dataset, validation_idx)

    cnn_model = Network().to(device) # init model

    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=90, shuffle=True, num_workers=1)
    test_dataloader = torch.utils.data.DataLoader(validation_dataset, batch_size=10, shuffle=False, num_workers=1)

    optimizer = optim.Adam(lr=0.01, params=cnn_model.parameters())
    # def train loop
    def get_item(preds, labels):
        """function that returns the accuracy of our architecture"""
        return preds.argmax(dim=1).eq(labels).sum().item()

    for epoch in range(10):
        start_time = time.time()
        total_correct = 0
        total_loss = 0
        for batch in train_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs) # get preds
            loss = F.cross_entropy(preds, lbls) # compute loss
            optimizer.zero_grad() # zero grads
            loss.backward() # calculates gradients 
            optimizer.step() # update the weights
            total_loss += loss.item()
        
        for batch in test_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs)
            total_correct += get_item(preds, lbls)
            accuracy = total_correct/len(validation_dataset)

        accuracy_epoch.append(accuracy)
        end_time = time.time() - start_time    
        print("Epoch no.",epoch+1 ,"|test accuracy: ", round(accuracy*100, 3),"%", "|total_loss: ", total_loss, "| epoch_duration: ", round(end_time,2),"sec")
    
    accuracies.append(accuracy_epoch)

  experiment_2_all_accuracies.append(accuracies)
# Out:
# Seed images collected!
# n = 50
# Epoch no. 1 |test accuracy:  16.0 % |total_loss:  23.03442144393921 | epoch_duration:  0.26 sec
# Epoch no. 2 |test accuracy:  20.0 % |total_loss:  14.265095114707947 | epoch_duration:  0.27 sec
# Epoch no. 3 |test accuracy:  42.0 % |total_loss:  7.687483787536621 | epoch_duration:  0.25 sec
# Epoch no. 4 |test accuracy:  40.0 % |total_loss:  4.531539082527161 | epoch_duration:  0.26 sec
# Epoch no. 5 |test accuracy:  50.0 % |total_loss:  2.88490754365921 | epoch_duration:  0.26 sec
# Epoch no. 6 |test accuracy:  48.0 % |total_loss:  1.2563428282737732 | epoch_duration:  0.27 sec
# Epoch no. 7 |test accuracy:  52.0 % |total_loss:  0.49726957827806473 | epoch_duration:  0.29 sec
# Epoch no. 8 |test accuracy:  52.0 % |total_loss:  0.2602148652076721 | epoch_duration:  0.29 sec
# Epoch no. 9 |test accuracy:  52.0 % |total_loss:  0.09473378863185644 | epoch_duration:  0.26 sec
# Epoch no. 10 |test accuracy:  54.0 % |total_loss:  0.05140847060829401 | epoch_duration:  0.27 sec
# n = 50
# Epoch no. 1 |test accuracy:  14.0 % |total_loss:  32.05810904502869 | epoch_duration:  0.26 sec
# Epoch no. 2 |test accuracy:  14.0 % |total_loss:  18.47684144973755 | epoch_duration:  0.27 sec
# Epoch no. 3 |test accuracy:  38.0 % |total_loss:  10.473437070846558 | epoch_duration:  0.27 sec
# Epoch no. 4 |test accuracy:  38.0 % |total_loss:  6.137102782726288 | epoch_duration:  0.27 sec
# Epoch no. 5 |test accuracy:  54.0 % |total_loss:  3.454778790473938 | epoch_duration:  0.28 sec
# Epoch no. 6 |test accuracy:  50.0 % |total_loss:  2.2078738510608673 | epoch_duration:  0.27 sec
# Epoch no. 7 |test accuracy:  62.0 % |total_loss:  1.0512182265520096 | epoch_duration:  0.27 sec
# Epoch no. 8 |test accuracy:  66.0 % |total_loss:  0.5739496797323227 | epoch_duration:  0.27 sec
# Epoch no. 9 |test accuracy:  66.0 % |total_loss:  0.2452859729528427 | epoch_duration:  0.27 sec
# Epoch no. 10 |test accuracy:  64.0 % |total_loss:  0.15914282388985157 | epoch_duration:  0.28 sec
# n = 50
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  18.745248794555664 | epoch_duration:  0.26 sec
# Epoch no. 2 |test accuracy:  30.0 % |total_loss:  9.410048246383667 | epoch_duration:  0.26 sec
# Epoch no. 3 |test accuracy:  34.0 % |total_loss:  5.316075623035431 | epoch_duration:  0.25 sec
# Epoch no. 4 |test accuracy:  44.0 % |total_loss:  2.904703378677368 | epoch_duration:  0.28 sec
# Epoch no. 5 |test accuracy:  44.0 % |total_loss:  1.135348305106163 | epoch_duration:  0.27 sec
# Epoch no. 6 |test accuracy:  54.0 % |total_loss:  0.47399573028087616 | epoch_duration:  0.26 sec
# Epoch no. 7 |test accuracy:  52.0 % |total_loss:  0.16286185570061207 | epoch_duration:  0.27 sec
# Epoch no. 8 |test accuracy:  42.0 % |total_loss:  0.058831581845879555 | epoch_duration:  0.27 sec
# Epoch no. 9 |test accuracy:  46.0 % |total_loss:  0.03565944358706474 | epoch_duration:  0.27 sec
# Epoch no. 10 |test accuracy:  50.0 % |total_loss:  0.020519088488072157 | epoch_duration:  0.26 sec
# n = 50
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  34.662455797195435 | epoch_duration:  0.26 sec
# Epoch no. 2 |test accuracy:  20.0 % |total_loss:  29.22626829147339 | epoch_duration:  0.27 sec
# Epoch no. 3 |test accuracy:  26.0 % |total_loss:  12.508999586105347 | epoch_duration:  0.25 sec
# Epoch no. 4 |test accuracy:  46.0 % |total_loss:  7.191641092300415 | epoch_duration:  0.26 sec
# Epoch no. 5 |test accuracy:  44.0 % |total_loss:  4.0161901116371155 | epoch_duration:  0.27 sec
# Epoch no. 6 |test accuracy:  58.0 % |total_loss:  2.861472249031067 | epoch_duration:  0.26 sec
# Epoch no. 7 |test accuracy:  64.0 % |total_loss:  1.7877249121665955 | epoch_duration:  0.27 sec
# Epoch no. 8 |test accuracy:  66.0 % |total_loss:  0.8306849449872971 | epoch_duration:  0.38 sec
# Epoch no. 9 |test accuracy:  64.0 % |total_loss:  0.5037809684872627 | epoch_duration:  0.38 sec
# Epoch no. 10 |test accuracy:  66.0 % |total_loss:  0.2748369686305523 | epoch_duration:  0.39 sec
# n = 50
# Epoch no. 1 |test accuracy:  14.0 % |total_loss:  21.777430534362793 | epoch_duration:  0.39 sec
# Epoch no. 2 |test accuracy:  22.0 % |total_loss:  14.508730173110962 | epoch_duration:  0.39 sec
# Epoch no. 3 |test accuracy:  32.0 % |total_loss:  7.934493064880371 | epoch_duration:  0.38 sec
# Epoch no. 4 |test accuracy:  40.0 % |total_loss:  4.3319936990737915 | epoch_duration:  0.33 sec
# Epoch no. 5 |test accuracy:  36.0 % |total_loss:  2.0826817750930786 | epoch_duration:  0.27 sec
# Epoch no. 6 |test accuracy:  44.0 % |total_loss:  0.9923375099897385 | epoch_duration:  0.26 sec
# Epoch no. 7 |test accuracy:  50.0 % |total_loss:  0.32542744278907776 | epoch_duration:  0.26 sec
# Epoch no. 8 |test accuracy:  48.0 % |total_loss:  0.11582918185740709 | epoch_duration:  0.25 sec
# Epoch no. 9 |test accuracy:  50.0 % |total_loss:  0.05438756011426449 | epoch_duration:  0.26 sec
# Epoch no. 10 |test accuracy:  50.0 % |total_loss:  0.026402932358905673 | epoch_duration:  0.26 sec
# n = 100
# Epoch no. 1 |test accuracy:  14.0 % |total_loss:  45.73307919502258 | epoch_duration:  0.36 sec
# Epoch no. 2 |test accuracy:  39.0 % |total_loss:  20.765018939971924 | epoch_duration:  0.38 sec
# Epoch no. 3 |test accuracy:  46.0 % |total_loss:  12.542127013206482 | epoch_duration:  0.34 sec
# Epoch no. 4 |test accuracy:  65.0 % |total_loss:  6.299532532691956 | epoch_duration:  0.34 sec
# Epoch no. 5 |test accuracy:  67.0 % |total_loss:  2.692405015230179 | epoch_duration:  0.36 sec
# Epoch no. 6 |test accuracy:  73.0 % |total_loss:  1.071002945303917 | epoch_duration:  0.35 sec
# Epoch no. 7 |test accuracy:  76.0 % |total_loss:  0.4645530954003334 | epoch_duration:  0.37 sec
# Epoch no. 8 |test accuracy:  78.0 % |total_loss:  0.19929843489080667 | epoch_duration:  0.35 sec
# Epoch no. 9 |test accuracy:  80.0 % |total_loss:  0.09891374502331018 | epoch_duration:  0.36 sec
# Epoch no. 10 |test accuracy:  78.0 % |total_loss:  0.05132728395983577 | epoch_duration:  0.35 sec
# n = 100
# Epoch no. 1 |test accuracy:  9.0 % |total_loss:  112.35198903083801 | epoch_duration:  0.35 sec
# Epoch no. 2 |test accuracy:  22.0 % |total_loss:  58.49653697013855 | epoch_duration:  0.36 sec
# Epoch no. 3 |test accuracy:  20.0 % |total_loss:  23.18709886074066 | epoch_duration:  0.35 sec
# Epoch no. 4 |test accuracy:  33.0 % |total_loss:  17.74063265323639 | epoch_duration:  0.35 sec
# Epoch no. 5 |test accuracy:  38.0 % |total_loss:  12.468799591064453 | epoch_duration:  0.39 sec
# Epoch no. 6 |test accuracy:  47.0 % |total_loss:  8.31913846731186 | epoch_duration:  0.35 sec
# Epoch no. 7 |test accuracy:  60.0 % |total_loss:  4.580636441707611 | epoch_duration:  0.36 sec
# Epoch no. 8 |test accuracy:  65.0 % |total_loss:  2.3778300285339355 | epoch_duration:  0.35 sec
# Epoch no. 9 |test accuracy:  66.0 % |total_loss:  1.2510873600840569 | epoch_duration:  0.35 sec
# Epoch no. 10 |test accuracy:  71.0 % |total_loss:  0.6037956178188324 | epoch_duration:  0.35 sec
# n = 100
# Epoch no. 1 |test accuracy:  16.0 % |total_loss:  44.12766122817993 | epoch_duration:  0.35 sec
# Epoch no. 2 |test accuracy:  41.0 % |total_loss:  18.555933594703674 | epoch_duration:  0.35 sec
# Epoch no. 3 |test accuracy:  50.0 % |total_loss:  9.157730281352997 | epoch_duration:  0.38 sec
# Epoch no. 4 |test accuracy:  66.0 % |total_loss:  3.9094533920288086 | epoch_duration:  0.55 sec
# Epoch no. 5 |test accuracy:  70.0 % |total_loss:  1.1241229847073555 | epoch_duration:  0.54 sec
# Epoch no. 6 |test accuracy:  69.0 % |total_loss:  0.4328623488545418 | epoch_duration:  0.56 sec
# Epoch no. 7 |test accuracy:  65.0 % |total_loss:  0.16976028680801392 | epoch_duration:  0.58 sec
# Epoch no. 8 |test accuracy:  71.0 % |total_loss:  0.09340391913428903 | epoch_duration:  0.46 sec
# Epoch no. 9 |test accuracy:  71.0 % |total_loss:  0.05539574287831783 | epoch_duration:  0.36 sec
# Epoch no. 10 |test accuracy:  70.0 % |total_loss:  0.03949683136306703 | epoch_duration:  0.35 sec
# n = 100
# Epoch no. 1 |test accuracy:  24.0 % |total_loss:  63.71334505081177 | epoch_duration:  0.36 sec
# Epoch no. 2 |test accuracy:  33.0 % |total_loss:  31.763935327529907 | epoch_duration:  0.35 sec
# Epoch no. 3 |test accuracy:  44.0 % |total_loss:  15.041521430015564 | epoch_duration:  0.36 sec
# Epoch no. 4 |test accuracy:  64.0 % |total_loss:  8.019973516464233 | epoch_duration:  0.35 sec
# Epoch no. 5 |test accuracy:  72.0 % |total_loss:  3.1341098099946976 | epoch_duration:  0.34 sec
# Epoch no. 6 |test accuracy:  79.0 % |total_loss:  1.1871354654431343 | epoch_duration:  0.36 sec
# Epoch no. 7 |test accuracy:  82.0 % |total_loss:  0.4684743322432041 | epoch_duration:  0.36 sec
# Epoch no. 8 |test accuracy:  84.0 % |total_loss:  0.18385400902479887 | epoch_duration:  0.36 sec
# Epoch no. 9 |test accuracy:  85.0 % |total_loss:  0.10536967869848013 | epoch_duration:  0.35 sec
# Epoch no. 10 |test accuracy:  84.0 % |total_loss:  0.06384564144536853 | epoch_duration:  0.38 sec
# n = 100
# Epoch no. 1 |test accuracy:  32.0 % |total_loss:  40.66934275627136 | epoch_duration:  0.36 sec
# Epoch no. 2 |test accuracy:  41.0 % |total_loss:  19.61072874069214 | epoch_duration:  0.38 sec
# Epoch no. 3 |test accuracy:  62.0 % |total_loss:  9.072593748569489 | epoch_duration:  0.37 sec
# Epoch no. 4 |test accuracy:  71.0 % |total_loss:  4.078149139881134 | epoch_duration:  0.34 sec
# Epoch no. 5 |test accuracy:  66.0 % |total_loss:  1.4478237554430962 | epoch_duration:  0.36 sec
# Epoch no. 6 |test accuracy:  71.0 % |total_loss:  0.5608149264007807 | epoch_duration:  0.34 sec
# Epoch no. 7 |test accuracy:  74.0 % |total_loss:  0.1907294001430273 | epoch_duration:  0.36 sec
# Epoch no. 8 |test accuracy:  73.0 % |total_loss:  0.09107780549675226 | epoch_duration:  0.36 sec
# Epoch no. 9 |test accuracy:  76.0 % |total_loss:  0.043056076392531395 | epoch_duration:  0.34 sec
# Epoch no. 10 |test accuracy:  75.0 % |total_loss:  0.032934691524133086 | epoch_duration:  0.35 sec
# n = 150
# Epoch no. 1 |test accuracy:  38.0 % |total_loss:  56.29305839538574 | epoch_duration:  0.45 sec
# Epoch no. 2 |test accuracy:  52.667 % |total_loss:  21.861408472061157 | epoch_duration:  0.43 sec
# Epoch no. 3 |test accuracy:  78.0 % |total_loss:  9.337511986494064 | epoch_duration:  0.48 sec
# Epoch no. 4 |test accuracy:  82.667 % |total_loss:  2.911297023296356 | epoch_duration:  0.44 sec
# Epoch no. 5 |test accuracy:  89.333 % |total_loss:  0.9585336968302727 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  87.333 % |total_loss:  0.3097786149010062 | epoch_duration:  0.71 sec
# Epoch no. 7 |test accuracy:  87.333 % |total_loss:  0.16738887503743172 | epoch_duration:  0.7 sec
# Epoch no. 8 |test accuracy:  90.0 % |total_loss:  0.10363741172477603 | epoch_duration:  0.64 sec
# Epoch no. 9 |test accuracy:  90.0 % |total_loss:  0.06444399221800268 | epoch_duration:  0.47 sec
# Epoch no. 10 |test accuracy:  88.667 % |total_loss:  0.0457883276976645 | epoch_duration:  0.47 sec
# n = 150
# Epoch no. 1 |test accuracy:  22.0 % |total_loss:  66.50814962387085 | epoch_duration:  0.44 sec
# Epoch no. 2 |test accuracy:  48.0 % |total_loss:  24.819736123085022 | epoch_duration:  0.49 sec
# Epoch no. 3 |test accuracy:  67.333 % |total_loss:  11.264382898807526 | epoch_duration:  0.43 sec
# Epoch no. 4 |test accuracy:  74.667 % |total_loss:  4.424624070525169 | epoch_duration:  0.45 sec
# Epoch no. 5 |test accuracy:  80.667 % |total_loss:  1.563051301985979 | epoch_duration:  0.43 sec
# Epoch no. 6 |test accuracy:  82.667 % |total_loss:  0.5197126213461161 | epoch_duration:  0.45 sec
# Epoch no. 7 |test accuracy:  83.333 % |total_loss:  0.19985610526055098 | epoch_duration:  0.45 sec
# Epoch no. 8 |test accuracy:  85.333 % |total_loss:  0.10229426622390747 | epoch_duration:  0.45 sec
# Epoch no. 9 |test accuracy:  85.333 % |total_loss:  0.06372056622058153 | epoch_duration:  0.46 sec
# Epoch no. 10 |test accuracy:  85.333 % |total_loss:  0.048885250464081764 | epoch_duration:  0.43 sec
# n = 150
# Epoch no. 1 |test accuracy:  21.333 % |total_loss:  73.28013920783997 | epoch_duration:  0.47 sec
# Epoch no. 2 |test accuracy:  50.667 % |total_loss:  25.46007001399994 | epoch_duration:  0.45 sec
# Epoch no. 3 |test accuracy:  66.667 % |total_loss:  13.221193730831146 | epoch_duration:  0.44 sec
# Epoch no. 4 |test accuracy:  71.333 % |total_loss:  6.7122281193733215 | epoch_duration:  0.47 sec
# Epoch no. 5 |test accuracy:  78.667 % |total_loss:  2.99027182161808 | epoch_duration:  0.45 sec
# Epoch no. 6 |test accuracy:  78.667 % |total_loss:  1.3163281679153442 | epoch_duration:  0.44 sec
# Epoch no. 7 |test accuracy:  84.667 % |total_loss:  0.5316359791904688 | epoch_duration:  0.46 sec
# Epoch no. 8 |test accuracy:  85.333 % |total_loss:  0.2322706338018179 | epoch_duration:  0.45 sec
# Epoch no. 9 |test accuracy:  85.333 % |total_loss:  0.1371663953177631 | epoch_duration:  0.44 sec
# Epoch no. 10 |test accuracy:  86.667 % |total_loss:  0.09802830498665571 | epoch_duration:  0.61 sec
# n = 150
# Epoch no. 1 |test accuracy:  24.667 % |total_loss:  56.14091610908508 | epoch_duration:  0.73 sec
# Epoch no. 2 |test accuracy:  53.333 % |total_loss:  20.26888531446457 | epoch_duration:  0.72 sec
# Epoch no. 3 |test accuracy:  74.667 % |total_loss:  7.604355961084366 | epoch_duration:  0.73 sec
# Epoch no. 4 |test accuracy:  81.333 % |total_loss:  2.4195780605077744 | epoch_duration:  0.46 sec
# Epoch no. 5 |test accuracy:  88.667 % |total_loss:  0.8121691960841417 | epoch_duration:  0.44 sec
# Epoch no. 6 |test accuracy:  90.667 % |total_loss:  0.2879621824249625 | epoch_duration:  0.46 sec
# Epoch no. 7 |test accuracy:  87.333 % |total_loss:  0.17681662691757083 | epoch_duration:  0.45 sec
# Epoch no. 8 |test accuracy:  86.0 % |total_loss:  0.09230867167934775 | epoch_duration:  0.46 sec
# Epoch no. 9 |test accuracy:  88.667 % |total_loss:  0.06290846294723451 | epoch_duration:  0.48 sec
# Epoch no. 10 |test accuracy:  88.0 % |total_loss:  0.04546844959259033 | epoch_duration:  0.47 sec
# n = 150
# Epoch no. 1 |test accuracy:  30.667 % |total_loss:  47.18247985839844 | epoch_duration:  0.48 sec
# Epoch no. 2 |test accuracy:  59.333 % |total_loss:  16.20599675178528 | epoch_duration:  0.47 sec
# Epoch no. 3 |test accuracy:  66.667 % |total_loss:  6.726960301399231 | epoch_duration:  0.45 sec
# Epoch no. 4 |test accuracy:  86.0 % |total_loss:  2.5443582981824875 | epoch_duration:  0.79 sec
# Epoch no. 5 |test accuracy:  88.667 % |total_loss:  0.6688974741846323 | epoch_duration:  0.44 sec
# Epoch no. 6 |test accuracy:  88.667 % |total_loss:  0.2658218890428543 | epoch_duration:  0.46 sec
# Epoch no. 7 |test accuracy:  92.0 % |total_loss:  0.12164565222337842 | epoch_duration:  0.47 sec
# Epoch no. 8 |test accuracy:  91.333 % |total_loss:  0.07106724102050066 | epoch_duration:  0.47 sec
# Epoch no. 9 |test accuracy:  90.667 % |total_loss:  0.05082422751002014 | epoch_duration:  0.46 sec
# Epoch no. 10 |test accuracy:  91.333 % |total_loss:  0.041357694659382105 | epoch_duration:  0.45 sec
# n = 200
# Epoch no. 1 |test accuracy:  36.5 % |total_loss:  100.94427037239075 | epoch_duration:  0.54 sec
# Epoch no. 2 |test accuracy:  63.5 % |total_loss:  27.21580970287323 | epoch_duration:  0.56 sec
# Epoch no. 3 |test accuracy:  86.5 % |total_loss:  9.637571066617966 | epoch_duration:  0.56 sec
# Epoch no. 4 |test accuracy:  93.5 % |total_loss:  2.861471712589264 | epoch_duration:  0.94 sec
# Epoch no. 5 |test accuracy:  92.0 % |total_loss:  0.8647464383393526 | epoch_duration:  0.91 sec
# Epoch no. 6 |test accuracy:  95.0 % |total_loss:  0.3669476956129074 | epoch_duration:  0.86 sec
# Epoch no. 7 |test accuracy:  95.5 % |total_loss:  0.1824746266938746 | epoch_duration:  0.53 sec
# Epoch no. 8 |test accuracy:  95.5 % |total_loss:  0.12286040978506207 | epoch_duration:  0.54 sec
# Epoch no. 9 |test accuracy:  95.5 % |total_loss:  0.09314562822692096 | epoch_duration:  0.54 sec
# Epoch no. 10 |test accuracy:  96.5 % |total_loss:  0.07578727835789323 | epoch_duration:  0.55 sec
# n = 200
# Epoch no. 1 |test accuracy:  42.5 % |total_loss:  62.596327900886536 | epoch_duration:  0.54 sec
# Epoch no. 2 |test accuracy:  71.0 % |total_loss:  19.911413550376892 | epoch_duration:  0.53 sec
# Epoch no. 3 |test accuracy:  86.0 % |total_loss:  5.632411599159241 | epoch_duration:  0.53 sec
# Epoch no. 4 |test accuracy:  90.0 % |total_loss:  2.009955123066902 | epoch_duration:  0.54 sec
# Epoch no. 5 |test accuracy:  91.5 % |total_loss:  0.7518475586548448 | epoch_duration:  0.53 sec
# Epoch no. 6 |test accuracy:  93.0 % |total_loss:  0.2378573571331799 | epoch_duration:  0.55 sec
# Epoch no. 7 |test accuracy:  93.5 % |total_loss:  0.08952314150519669 | epoch_duration:  0.53 sec
# Epoch no. 8 |test accuracy:  93.5 % |total_loss:  0.05450927861966193 | epoch_duration:  0.56 sec
# Epoch no. 9 |test accuracy:  93.5 % |total_loss:  0.04082012840081006 | epoch_duration:  0.51 sec
# Epoch no. 10 |test accuracy:  93.5 % |total_loss:  0.03304151422344148 | epoch_duration:  0.55 sec
# n = 200
# Epoch no. 1 |test accuracy:  40.5 % |total_loss:  81.67395842075348 | epoch_duration:  0.53 sec
# Epoch no. 2 |test accuracy:  75.5 % |total_loss:  22.42066127061844 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  88.0 % |total_loss:  6.150680124759674 | epoch_duration:  1.28 sec
# Epoch no. 4 |test accuracy:  92.0 % |total_loss:  2.080777872353792 | epoch_duration:  2.42 sec
# Epoch no. 5 |test accuracy:  97.0 % |total_loss:  0.4723700173199177 | epoch_duration:  1.28 sec
# Epoch no. 6 |test accuracy:  98.0 % |total_loss:  0.15265300404280424 | epoch_duration:  0.87 sec
# Epoch no. 7 |test accuracy:  97.5 % |total_loss:  0.08211189857684076 | epoch_duration:  0.56 sec
# Epoch no. 8 |test accuracy:  98.5 % |total_loss:  0.05136738542933017 | epoch_duration:  0.56 sec
# Epoch no. 9 |test accuracy:  98.0 % |total_loss:  0.03883336833678186 | epoch_duration:  0.56 sec
# Epoch no. 10 |test accuracy:  98.5 % |total_loss:  0.033031130442395806 | epoch_duration:  0.53 sec
# n = 200
# Epoch no. 1 |test accuracy:  38.5 % |total_loss:  75.0617128610611 | epoch_duration:  0.54 sec
# Epoch no. 2 |test accuracy:  68.0 % |total_loss:  22.157801866531372 | epoch_duration:  0.53 sec
# Epoch no. 3 |test accuracy:  82.0 % |total_loss:  7.698781430721283 | epoch_duration:  0.55 sec
# Epoch no. 4 |test accuracy:  94.5 % |total_loss:  2.3224271535873413 | epoch_duration:  0.53 sec
# Epoch no. 5 |test accuracy:  96.0 % |total_loss:  0.663807138800621 | epoch_duration:  0.55 sec
# Epoch no. 6 |test accuracy:  97.5 % |total_loss:  0.24011548003181815 | epoch_duration:  0.53 sec
# Epoch no. 7 |test accuracy:  97.5 % |total_loss:  0.14181547705084085 | epoch_duration:  0.56 sec
# Epoch no. 8 |test accuracy:  97.5 % |total_loss:  0.07588925305753946 | epoch_duration:  0.52 sec
# Epoch no. 9 |test accuracy:  97.5 % |total_loss:  0.05248398706316948 | epoch_duration:  0.55 sec
# Epoch no. 10 |test accuracy:  97.5 % |total_loss:  0.04153099900577217 | epoch_duration:  0.55 sec
# n = 200
# Epoch no. 1 |test accuracy:  35.5 % |total_loss:  81.76876890659332 | epoch_duration:  0.54 sec
# Epoch no. 2 |test accuracy:  67.5 % |total_loss:  25.47962248325348 | epoch_duration:  0.9 sec
# Epoch no. 3 |test accuracy:  83.5 % |total_loss:  8.016857758164406 | epoch_duration:  0.9 sec
# Epoch no. 4 |test accuracy:  89.5 % |total_loss:  2.3757083900272846 | epoch_duration:  0.85 sec
# Epoch no. 5 |test accuracy:  92.0 % |total_loss:  0.8370060715824366 | epoch_duration:  0.54 sec
# Epoch no. 6 |test accuracy:  94.0 % |total_loss:  0.3174350722692907 | epoch_duration:  0.54 sec
# Epoch no. 7 |test accuracy:  94.0 % |total_loss:  0.14519654121249914 | epoch_duration:  0.52 sec
# Epoch no. 8 |test accuracy:  95.0 % |total_loss:  0.08601847453974187 | epoch_duration:  0.56 sec
# Epoch no. 9 |test accuracy:  94.5 % |total_loss:  0.06436591944657266 | epoch_duration:  0.54 sec
# Epoch no. 10 |test accuracy:  95.0 % |total_loss:  0.05217190599068999 | epoch_duration:  0.56 sec
# n = 300
# Epoch no. 1 |test accuracy:  60.667 % |total_loss:  98.75809872150421 | epoch_duration:  0.73 sec
# Epoch no. 2 |test accuracy:  91.333 % |total_loss:  13.259647436439991 | epoch_duration:  0.72 sec
# Epoch no. 3 |test accuracy:  96.0 % |total_loss:  1.8523560166358948 | epoch_duration:  0.71 sec
# Epoch no. 4 |test accuracy:  97.333 % |total_loss:  0.36476951744407415 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  97.667 % |total_loss:  0.11823173065204173 | epoch_duration:  0.71 sec
# Epoch no. 6 |test accuracy:  98.0 % |total_loss:  0.06855412083677948 | epoch_duration:  0.71 sec
# Epoch no. 7 |test accuracy:  98.0 % |total_loss:  0.05081533791963011 | epoch_duration:  0.73 sec
# Epoch no. 8 |test accuracy:  97.667 % |total_loss:  0.040624845190905035 | epoch_duration:  0.71 sec
# Epoch no. 9 |test accuracy:  97.667 % |total_loss:  0.03365243028383702 | epoch_duration:  0.71 sec
# Epoch no. 10 |test accuracy:  97.667 % |total_loss:  0.028234484198037535 | epoch_duration:  1.07 sec
# n = 300
# Epoch no. 1 |test accuracy:  59.667 % |total_loss:  69.92121982574463 | epoch_duration:  1.25 sec
# Epoch no. 2 |test accuracy:  89.667 % |total_loss:  15.495450168848038 | epoch_duration:  0.87 sec
# Epoch no. 3 |test accuracy:  93.333 % |total_loss:  3.141545455902815 | epoch_duration:  0.72 sec
# Epoch no. 4 |test accuracy:  96.0 % |total_loss:  0.7868753215298057 | epoch_duration:  0.71 sec
# Epoch no. 5 |test accuracy:  96.0 % |total_loss:  0.2081417036242783 | epoch_duration:  0.71 sec
# Epoch no. 6 |test accuracy:  96.667 % |total_loss:  0.09183857345487922 | epoch_duration:  0.71 sec
# Epoch no. 7 |test accuracy:  96.667 % |total_loss:  0.0506502139614895 | epoch_duration:  0.73 sec
# Epoch no. 8 |test accuracy:  96.667 % |total_loss:  0.03706954239169136 | epoch_duration:  0.74 sec
# Epoch no. 9 |test accuracy:  96.667 % |total_loss:  0.030079495045356452 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  96.667 % |total_loss:  0.025464456935878843 | epoch_duration:  0.72 sec
# n = 300
# Epoch no. 1 |test accuracy:  48.333 % |total_loss:  109.97386193275452 | epoch_duration:  0.71 sec
# Epoch no. 2 |test accuracy:  87.333 % |total_loss:  21.550129175186157 | epoch_duration:  0.72 sec
# Epoch no. 3 |test accuracy:  97.0 % |total_loss:  4.434031784534454 | epoch_duration:  0.69 sec
# Epoch no. 4 |test accuracy:  98.667 % |total_loss:  1.039725512266159 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  98.667 % |total_loss:  0.3106891280040145 | epoch_duration:  0.76 sec
# Epoch no. 6 |test accuracy:  99.0 % |total_loss:  0.1494214148260653 | epoch_duration:  1.22 sec
# Epoch no. 7 |test accuracy:  98.667 % |total_loss:  0.09686056477949023 | epoch_duration:  1.19 sec
# Epoch no. 8 |test accuracy:  99.0 % |total_loss:  0.07450672169215977 | epoch_duration:  0.83 sec
# Epoch no. 9 |test accuracy:  98.667 % |total_loss:  0.060001849895343184 | epoch_duration:  0.72 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  0.050396231352351606 | epoch_duration:  0.72 sec
# n = 300
# Epoch no. 1 |test accuracy:  70.333 % |total_loss:  72.48882097005844 | epoch_duration:  0.72 sec
# Epoch no. 2 |test accuracy:  94.667 % |total_loss:  10.469845294952393 | epoch_duration:  0.71 sec
# Epoch no. 3 |test accuracy:  98.333 % |total_loss:  1.5180684858933091 | epoch_duration:  0.71 sec
# Epoch no. 4 |test accuracy:  99.0 % |total_loss:  0.29080351791344583 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  99.0 % |total_loss:  0.08504394418559968 | epoch_duration:  0.73 sec
# Epoch no. 6 |test accuracy:  99.333 % |total_loss:  0.04298451397335157 | epoch_duration:  0.73 sec
# Epoch no. 7 |test accuracy:  99.0 % |total_loss:  0.031548417755402625 | epoch_duration:  0.71 sec
# Epoch no. 8 |test accuracy:  99.333 % |total_loss:  0.0255968383862637 | epoch_duration:  0.71 sec
# Epoch no. 9 |test accuracy:  99.667 % |total_loss:  0.02141272375592962 | epoch_duration:  0.72 sec
# Epoch no. 10 |test accuracy:  99.667 % |total_loss:  0.018257096002344042 | epoch_duration:  0.71 sec
# n = 300
# Epoch no. 1 |test accuracy:  73.667 % |total_loss:  66.69803297519684 | epoch_duration:  0.77 sec
# Epoch no. 2 |test accuracy:  87.667 % |total_loss:  10.19962453097105 | epoch_duration:  1.25 sec
# Epoch no. 3 |test accuracy:  94.0 % |total_loss:  2.271867711097002 | epoch_duration:  1.27 sec
# Epoch no. 4 |test accuracy:  96.333 % |total_loss:  0.6167230354622006 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  96.333 % |total_loss:  0.19019564101472497 | epoch_duration:  0.72 sec
# Epoch no. 6 |test accuracy:  96.667 % |total_loss:  0.05824611824937165 | epoch_duration:  0.76 sec
# Epoch no. 7 |test accuracy:  97.0 % |total_loss:  0.030676640511956066 | epoch_duration:  0.74 sec
# Epoch no. 8 |test accuracy:  96.667 % |total_loss:  0.02321014937479049 | epoch_duration:  0.7 sec
# Epoch no. 9 |test accuracy:  97.0 % |total_loss:  0.01887267892016098 | epoch_duration:  0.7 sec
# Epoch no. 10 |test accuracy:  97.0 % |total_loss:  0.01603548225830309 | epoch_duration:  0.7 sec
# n = 400
# Epoch no. 1 |test accuracy:  68.0 % |total_loss:  120.96863824129105 | epoch_duration:  0.9 sec
# Epoch no. 2 |test accuracy:  96.5 % |total_loss:  13.060254953801632 | epoch_duration:  0.88 sec
# Epoch no. 3 |test accuracy:  98.75 % |total_loss:  1.9766675792634487 | epoch_duration:  0.89 sec
# Epoch no. 4 |test accuracy:  99.0 % |total_loss:  0.42902239225804806 | epoch_duration:  0.88 sec
# Epoch no. 5 |test accuracy:  99.0 % |total_loss:  0.12160089856479317 | epoch_duration:  0.89 sec
# Epoch no. 6 |test accuracy:  99.0 % |total_loss:  0.07055707473773509 | epoch_duration:  1.27 sec
# Epoch no. 7 |test accuracy:  99.0 % |total_loss:  0.05193936551222578 | epoch_duration:  1.56 sec
# Epoch no. 8 |test accuracy:  99.0 % |total_loss:  0.04198534949682653 | epoch_duration:  0.98 sec
# Epoch no. 9 |test accuracy:  98.75 % |total_loss:  0.034527171577792615 | epoch_duration:  0.9 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  0.029294718377059326 | epoch_duration:  0.88 sec
# n = 400
# Epoch no. 1 |test accuracy:  83.5 % |total_loss:  94.35112357139587 | epoch_duration:  0.89 sec
# Epoch no. 2 |test accuracy:  96.0 % |total_loss:  8.761288404464722 | epoch_duration:  0.91 sec
# Epoch no. 3 |test accuracy:  99.0 % |total_loss:  1.450467061251402 | epoch_duration:  0.91 sec
# Epoch no. 4 |test accuracy:  99.5 % |total_loss:  0.4305042552296072 | epoch_duration:  0.91 sec
# Epoch no. 5 |test accuracy:  99.5 % |total_loss:  0.13393627596087754 | epoch_duration:  0.91 sec
# Epoch no. 6 |test accuracy:  99.5 % |total_loss:  0.08271906920708716 | epoch_duration:  0.89 sec
# Epoch no. 7 |test accuracy:  99.5 % |total_loss:  0.06226154463365674 | epoch_duration:  0.93 sec
# Epoch no. 8 |test accuracy:  99.5 % |total_loss:  0.04960755485808477 | epoch_duration:  0.9 sec
# Epoch no. 9 |test accuracy:  99.5 % |total_loss:  0.0409392777364701 | epoch_duration:  1.52 sec
# Epoch no. 10 |test accuracy:  99.5 % |total_loss:  0.03393735864665359 | epoch_duration:  1.51 sec
# n = 400
# Epoch no. 1 |test accuracy:  65.25 % |total_loss:  136.8976935148239 | epoch_duration:  0.87 sec
# Epoch no. 2 |test accuracy:  92.0 % |total_loss:  19.409117490053177 | epoch_duration:  0.88 sec
# Epoch no. 3 |test accuracy:  99.0 % |total_loss:  4.541277281939983 | epoch_duration:  0.88 sec
# Epoch no. 4 |test accuracy:  97.75 % |total_loss:  1.5010499497875571 | epoch_duration:  0.91 sec
# Epoch no. 5 |test accuracy:  98.5 % |total_loss:  0.6600416516885161 | epoch_duration:  0.88 sec
# Epoch no. 6 |test accuracy:  99.25 % |total_loss:  0.4801523806527257 | epoch_duration:  0.89 sec
# Epoch no. 7 |test accuracy:  99.5 % |total_loss:  0.12841538665816188 | epoch_duration:  0.9 sec
# Epoch no. 8 |test accuracy:  99.5 % |total_loss:  0.07057061314117163 | epoch_duration:  0.91 sec
# Epoch no. 9 |test accuracy:  99.5 % |total_loss:  0.05135001247981563 | epoch_duration:  0.89 sec
# Epoch no. 10 |test accuracy:  99.75 % |total_loss:  0.04142241453519091 | epoch_duration:  0.88 sec
# n = 400
# Epoch no. 1 |test accuracy:  58.5 % |total_loss:  137.12925446033478 | epoch_duration:  1.01 sec
# Epoch no. 2 |test accuracy:  86.75 % |total_loss:  24.777530312538147 | epoch_duration:  1.58 sec
# Epoch no. 3 |test accuracy:  97.5 % |total_loss:  4.650734186172485 | epoch_duration:  1.22 sec
# Epoch no. 4 |test accuracy:  97.5 % |total_loss:  1.0231325374916196 | epoch_duration:  0.89 sec
# Epoch no. 5 |test accuracy:  99.0 % |total_loss:  0.2764592033345252 | epoch_duration:  0.89 sec
# Epoch no. 6 |test accuracy:  99.0 % |total_loss:  0.12618278909940273 | epoch_duration:  0.89 sec
# Epoch no. 7 |test accuracy:  98.75 % |total_loss:  0.0798720046877861 | epoch_duration:  0.94 sec
# Epoch no. 8 |test accuracy:  99.0 % |total_loss:  0.06191038223914802 | epoch_duration:  0.88 sec
# Epoch no. 9 |test accuracy:  99.0 % |total_loss:  0.05043700977694243 | epoch_duration:  0.88 sec
# Epoch no. 10 |test accuracy:  99.0 % |total_loss:  0.04226938559440896 | epoch_duration:  0.89 sec
# n = 400
# Epoch no. 1 |test accuracy:  70.0 % |total_loss:  113.62412059307098 | epoch_duration:  0.87 sec
# Epoch no. 2 |test accuracy:  94.0 % |total_loss:  14.611550629138947 | epoch_duration:  0.91 sec
# Epoch no. 3 |test accuracy:  96.75 % |total_loss:  2.0267155384644866 | epoch_duration:  0.91 sec
# Epoch no. 4 |test accuracy:  97.75 % |total_loss:  0.46610960084944963 | epoch_duration:  1.15 sec
# Epoch no. 5 |test accuracy:  98.25 % |total_loss:  0.12697530584409833 | epoch_duration:  1.55 sec
# Epoch no. 6 |test accuracy:  98.25 % |total_loss:  0.07414085511118174 | epoch_duration:  1.03 sec
# Epoch no. 7 |test accuracy:  98.25 % |total_loss:  0.05328382452717051 | epoch_duration:  0.88 sec
# Epoch no. 8 |test accuracy:  98.25 % |total_loss:  0.0424807557137683 | epoch_duration:  0.91 sec
# Epoch no. 9 |test accuracy:  98.25 % |total_loss:  0.03480816283263266 | epoch_duration:  0.92 sec
# Epoch no. 10 |test accuracy:  98.5 % |total_loss:  0.029409018578007817 | epoch_duration:  0.88 sec

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

epochs = [i for i in range(10)]
 
for i in range(len(dataset_sizes)):
  plt.plot(epochs, np.mean(np.asarray(experiment_2_all_accuracies)[i,:,:], axis=0), label=str(dataset_sizes[i]*10))

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("MNIST - Simple Convnet")
plt.legend(title="Dataset size")

# %% [markdown]
# ## Experiments with number of seed images

# %% [markdown]
# ### Modified LeNet

# %%
class Network(nn.Module): # extend nn.Module class of nn
    def __init__(self):
        super().__init__() # super class constructor
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(5,5))
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=12, kernel_size=(5,5))
        self.fc1 = nn.Linear(in_features=12*6*6, out_features=120)
        self.fc2 = nn.Linear(in_features=120, out_features=60)
        self.out = nn.Linear(in_features=60, out_features=10)
        
    def forward(self, t): # implements the forward method (flow of tensors)
        
        # hidden conv layer 
        t = self.conv1(t) 
        t = F.max_pool2d(input=t, kernel_size=2, stride=2) 
        t = F.relu(t)
        
        # hidden conv layer
        t = self.conv2(t) 
        t = F.max_pool2d(input=t, kernel_size=2, stride=2) 
        t = F.relu(t)
        
        # flatten
        t = t.reshape(-1, 12*6*6)
        t = self.fc1(t)
        t = F.relu(t)
        t = self.fc2(t)
        t = F.relu(t)
        
        # output
        t = self.out(t)
        
        return t

# %%
n = 320
k_list = [1, 2, 4, 8, 16, 32]
n_classes = 10

seed_image_experiment_1 = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for k in k_list:
  
  accuracies = []
  seed_images, classes = get_seed_images(k=k)

  for j in range(5):
    accuracy_epoch = []    
    print(f"Number of seed_images = {k}")
    dataset_images = torch.zeros(n*n_classes,1,39,39) 
    dataset_labels = einops.repeat(torch.tensor(classes), 'n -> (repeat n)', repeat=n//k)

    for i in range(n//k):
      new_images = augment(device, seed_images)
      dataset_images[n_classes*k*i:n_classes*k*i+n_classes*k] = new_images


    dataset = Augmented_Dataset(dataset_images, dataset_labels)

    train_idx, validation_idx = train_test_split(np.arange(len(dataset)),
                                                test_size=0.1,
                                                random_state=999,
                                                shuffle=True,
                                                stratify=dataset.labels)

    train_dataset = Subset(dataset, train_idx)
    validation_dataset = Subset(dataset, validation_idx)

    cnn_model = Network().to(device) # init model

    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=90, shuffle=True, num_workers=1)
    test_dataloader = torch.utils.data.DataLoader(validation_dataset, batch_size=10, shuffle=False, num_workers=1)

    optimizer = optim.Adam(lr=0.01, params=cnn_model.parameters())
    # def train loop
    def get_item(preds, labels):
        """function that returns the accuracy of our architecture"""
        return preds.argmax(dim=1).eq(labels).sum().item()

    for epoch in range(10):
        start_time = time.time()
        total_correct = 0
        total_loss = 0
        for batch in train_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs) # get preds
            loss = F.cross_entropy(preds, lbls) # compute loss
            optimizer.zero_grad() # zero grads
            loss.backward() # calculates gradients 
            optimizer.step() # update the weights
            total_loss += loss.item()
        
        for batch in test_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs)
            total_correct += get_item(preds, lbls)
            accuracy = total_correct/len(validation_dataset)

        accuracy_epoch.append(accuracy)
        end_time = time.time() - start_time    
        print("Epoch no.",epoch+1 ,"|test accuracy: ", round(accuracy*100, 3),"%", "|total_loss: ", total_loss, "| epoch_duration: ", round(end_time,2),"sec")

    accuracies.append(accuracy_epoch)
  seed_image_experiment_1.append(accuracies)
# Out:
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  83.125 % |total_loss:  38.30919423699379 | epoch_duration:  1.2 sec
# Epoch no. 2 |test accuracy:  98.75 % |total_loss:  2.2753368127159774 | epoch_duration:  1.94 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  0.17918221581567195 | epoch_duration:  1.49 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.08205380723666167 | epoch_duration:  1.16 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.008549919502002012 | epoch_duration:  1.18 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.0014362785436787817 | epoch_duration:  1.21 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.0005115844978718087 | epoch_duration:  1.17 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.00032925416189755197 | epoch_duration:  1.16 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0002741078401413688 | epoch_duration:  1.18 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0002371894431689725 | epoch_duration:  1.16 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  96.875 % |total_loss:  38.032161712646484 | epoch_duration:  1.31 sec
# Epoch no. 2 |test accuracy:  74.688 % |total_loss:  2.9426773651503026 | epoch_duration:  1.92 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  2.8637017207220197 | epoch_duration:  1.32 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.07208490301854908 | epoch_duration:  1.21 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.0068611632523243316 | epoch_duration:  1.22 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.0028739476729242597 | epoch_duration:  1.18 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.002085062089463463 | epoch_duration:  1.36 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.00168092840067402 | epoch_duration:  1.19 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0013941759425506461 | epoch_duration:  1.18 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0011720135416908306 | epoch_duration:  1.2 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  94.688 % |total_loss:  39.85848093777895 | epoch_duration:  1.71 sec
# Epoch no. 2 |test accuracy:  100.0 % |total_loss:  2.4107860138174146 | epoch_duration:  1.74 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  0.28572930819063913 | epoch_duration:  1.17 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.08996484419913031 | epoch_duration:  1.21 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.005335452207873459 | epoch_duration:  1.17 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.0009707008684927132 | epoch_duration:  1.22 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.0006488181898021139 | epoch_duration:  1.17 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.000526213592820568 | epoch_duration:  1.16 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0004436149356479291 | epoch_duration:  1.17 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.00038786989284744777 | epoch_duration:  1.19 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  94.062 % |total_loss:  31.305536404252052 | epoch_duration:  1.94 sec
# Epoch no. 2 |test accuracy:  100.0 % |total_loss:  1.944911336991936 | epoch_duration:  1.54 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  0.03489107331552077 | epoch_duration:  1.18 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.0040876425246096915 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.002030973158980487 | epoch_duration:  1.21 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.0013434512657113373 | epoch_duration:  1.2 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.0010210323789578979 | epoch_duration:  1.21 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.0007910752988209424 | epoch_duration:  1.17 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0006169794528432249 | epoch_duration:  1.21 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0005910788358960417 | epoch_duration:  1.3 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  99.688 % |total_loss:  32.30904080718756 | epoch_duration:  1.99 sec
# Epoch no. 2 |test accuracy:  100.0 % |total_loss:  0.27328174840658903 | epoch_duration:  1.24 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  0.012619420973351225 | epoch_duration:  1.17 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.0012596843807841651 | epoch_duration:  1.21 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.0008036910749069648 | epoch_duration:  1.2 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.0006374459017024492 | epoch_duration:  1.18 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.000532237457264273 | epoch_duration:  1.22 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.00045521398351411335 | epoch_duration:  1.2 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0003938756867682969 | epoch_duration:  1.16 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0003453574317973107 | epoch_duration:  1.55 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  84.688 % |total_loss:  49.23154166340828 | epoch_duration:  1.2 sec
# Epoch no. 2 |test accuracy:  98.438 % |total_loss:  6.892769459635019 | epoch_duration:  1.17 sec
# Epoch no. 3 |test accuracy:  99.375 % |total_loss:  1.1017763097770512 | epoch_duration:  1.16 sec
# Epoch no. 4 |test accuracy:  99.062 % |total_loss:  0.9119343684287742 | epoch_duration:  1.22 sec
# Epoch no. 5 |test accuracy:  99.375 % |total_loss:  0.5022973248851486 | epoch_duration:  1.17 sec
# Epoch no. 6 |test accuracy:  98.75 % |total_loss:  0.12451104550564196 | epoch_duration:  1.25 sec
# Epoch no. 7 |test accuracy:  98.75 % |total_loss:  1.552561539618182 | epoch_duration:  1.92 sec
# Epoch no. 8 |test accuracy:  96.562 % |total_loss:  1.9245696492725983 | epoch_duration:  1.45 sec
# Epoch no. 9 |test accuracy:  96.875 % |total_loss:  1.7138980579329655 | epoch_duration:  1.22 sec
# Epoch no. 10 |test accuracy:  98.75 % |total_loss:  1.0580364003544673 | epoch_duration:  1.18 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  79.688 % |total_loss:  52.534470558166504 | epoch_duration:  1.17 sec
# Epoch no. 2 |test accuracy:  98.125 % |total_loss:  9.261568857356906 | epoch_duration:  1.17 sec
# Epoch no. 3 |test accuracy:  99.375 % |total_loss:  0.8915145816281438 | epoch_duration:  1.2 sec
# Epoch no. 4 |test accuracy:  99.375 % |total_loss:  2.0642755953595042 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.4991340116248466 | epoch_duration:  1.18 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.02261932095279917 | epoch_duration:  1.38 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.007343388737353962 | epoch_duration:  1.95 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.004675414013036061 | epoch_duration:  1.28 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.0035904674150515348 | epoch_duration:  1.2 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0029137347773939837 | epoch_duration:  1.19 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  89.375 % |total_loss:  47.90645730495453 | epoch_duration:  1.21 sec
# Epoch no. 2 |test accuracy:  98.438 % |total_loss:  7.087553903460503 | epoch_duration:  1.21 sec
# Epoch no. 3 |test accuracy:  98.75 % |total_loss:  1.165228245779872 | epoch_duration:  1.19 sec
# Epoch no. 4 |test accuracy:  99.688 % |total_loss:  0.16579463693778962 | epoch_duration:  1.23 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.015317546778533142 | epoch_duration:  1.19 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.004770577201270498 | epoch_duration:  1.68 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.0018710401727730641 | epoch_duration:  1.8 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.0008811582310954691 | epoch_duration:  1.23 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.00048107624070325983 | epoch_duration:  1.19 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.0013085013088129926 | epoch_duration:  1.18 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  83.438 % |total_loss:  47.12564143538475 | epoch_duration:  1.22 sec
# Epoch no. 2 |test accuracy:  96.875 % |total_loss:  5.161835949867964 | epoch_duration:  1.22 sec
# Epoch no. 3 |test accuracy:  99.688 % |total_loss:  1.3828126341104507 | epoch_duration:  1.2 sec
# Epoch no. 4 |test accuracy:  98.125 % |total_loss:  1.240805011242628 | epoch_duration:  1.17 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  1.4063470247201622 | epoch_duration:  1.21 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.2814446336997207 | epoch_duration:  1.97 sec
# Epoch no. 7 |test accuracy:  97.188 % |total_loss:  2.0039341164992948 | epoch_duration:  1.49 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  1.250757347443141 | epoch_duration:  1.23 sec
# Epoch no. 9 |test accuracy:  99.375 % |total_loss:  0.06628685996838612 | epoch_duration:  1.22 sec
# Epoch no. 10 |test accuracy:  99.375 % |total_loss:  0.004087858869752381 | epoch_duration:  1.19 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  64.062 % |total_loss:  58.13182061910629 | epoch_duration:  1.2 sec
# Epoch no. 2 |test accuracy:  94.375 % |total_loss:  14.579723477363586 | epoch_duration:  1.2 sec
# Epoch no. 3 |test accuracy:  99.688 % |total_loss:  2.188228185288608 | epoch_duration:  1.17 sec
# Epoch no. 4 |test accuracy:  82.188 % |total_loss:  2.665090690832585 | epoch_duration:  1.17 sec
# Epoch no. 5 |test accuracy:  98.125 % |total_loss:  4.8523366041481495 | epoch_duration:  1.39 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.3609340488910675 | epoch_duration:  1.94 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.07606388613930903 | epoch_duration:  1.21 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.015126826445339248 | epoch_duration:  1.18 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.007697160646785051 | epoch_duration:  1.21 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.005375406424718676 | epoch_duration:  1.21 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  73.97268033027649 | epoch_duration:  1.23 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  73.72494912147522 | epoch_duration:  1.91 sec
# Epoch no. 3 |test accuracy:  10.0 % |total_loss:  73.72611927986145 | epoch_duration:  1.55 sec
# Epoch no. 4 |test accuracy:  10.0 % |total_loss:  73.71867752075195 | epoch_duration:  1.19 sec
# Epoch no. 5 |test accuracy:  10.0 % |total_loss:  73.72518110275269 | epoch_duration:  1.18 sec
# Epoch no. 6 |test accuracy:  10.0 % |total_loss:  73.7109682559967 | epoch_duration:  1.2 sec
# Epoch no. 7 |test accuracy:  10.0 % |total_loss:  73.71146726608276 | epoch_duration:  1.2 sec
# Epoch no. 8 |test accuracy:  10.0 % |total_loss:  73.70868635177612 | epoch_duration:  1.19 sec
# Epoch no. 9 |test accuracy:  10.0 % |total_loss:  73.7044084072113 | epoch_duration:  1.17 sec
# Epoch no. 10 |test accuracy:  10.0 % |total_loss:  73.70712637901306 | epoch_duration:  1.18 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  62.187 % |total_loss:  62.84437704086304 | epoch_duration:  1.29 sec
# Epoch no. 2 |test accuracy:  84.688 % |total_loss:  21.44072899222374 | epoch_duration:  1.96 sec
# Epoch no. 3 |test accuracy:  97.188 % |total_loss:  5.681577201932669 | epoch_duration:  1.34 sec
# Epoch no. 4 |test accuracy:  95.625 % |total_loss:  2.3050508685410023 | epoch_duration:  1.21 sec
# Epoch no. 5 |test accuracy:  97.812 % |total_loss:  2.2215453861281276 | epoch_duration:  1.19 sec
# Epoch no. 6 |test accuracy:  96.875 % |total_loss:  1.7856654841452837 | epoch_duration:  1.19 sec
# Epoch no. 7 |test accuracy:  97.5 % |total_loss:  0.4098211213131435 | epoch_duration:  1.18 sec
# Epoch no. 8 |test accuracy:  99.375 % |total_loss:  0.3582633137848461 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  99.375 % |total_loss:  0.14121161958610173 | epoch_duration:  1.2 sec
# Epoch no. 10 |test accuracy:  99.062 % |total_loss:  0.022664800279017072 | epoch_duration:  1.19 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  40.938 % |total_loss:  67.46570467948914 | epoch_duration:  1.58 sec
# Epoch no. 2 |test accuracy:  66.875 % |total_loss:  40.27718824148178 | epoch_duration:  1.88 sec
# Epoch no. 3 |test accuracy:  84.062 % |total_loss:  19.638153344392776 | epoch_duration:  1.2 sec
# Epoch no. 4 |test accuracy:  93.438 % |total_loss:  8.72098195552826 | epoch_duration:  1.19 sec
# Epoch no. 5 |test accuracy:  89.375 % |total_loss:  6.160871081054211 | epoch_duration:  1.17 sec
# Epoch no. 6 |test accuracy:  94.688 % |total_loss:  5.696726892143488 | epoch_duration:  1.19 sec
# Epoch no. 7 |test accuracy:  95.312 % |total_loss:  2.1866085827350616 | epoch_duration:  1.19 sec
# Epoch no. 8 |test accuracy:  96.25 % |total_loss:  2.1298513347283006 | epoch_duration:  1.17 sec
# Epoch no. 9 |test accuracy:  98.125 % |total_loss:  1.3486301857046783 | epoch_duration:  1.18 sec
# Epoch no. 10 |test accuracy:  97.5 % |total_loss:  2.153771393932402 | epoch_duration:  1.21 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  39.688 % |total_loss:  66.84634804725647 | epoch_duration:  1.85 sec
# Epoch no. 2 |test accuracy:  74.688 % |total_loss:  37.82264405488968 | epoch_duration:  1.63 sec
# Epoch no. 3 |test accuracy:  92.812 % |total_loss:  13.372676864266396 | epoch_duration:  1.17 sec
# Epoch no. 4 |test accuracy:  96.875 % |total_loss:  5.756836097687483 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  98.438 % |total_loss:  3.345897898077965 | epoch_duration:  1.18 sec
# Epoch no. 6 |test accuracy:  91.25 % |total_loss:  2.998648338019848 | epoch_duration:  1.21 sec
# Epoch no. 7 |test accuracy:  96.875 % |total_loss:  2.2940384754911065 | epoch_duration:  1.2 sec
# Epoch no. 8 |test accuracy:  93.75 % |total_loss:  1.963672394049354 | epoch_duration:  1.2 sec
# Epoch no. 9 |test accuracy:  98.438 % |total_loss:  4.636194594204426 | epoch_duration:  1.19 sec
# Epoch no. 10 |test accuracy:  99.375 % |total_loss:  1.5636959904804826 | epoch_duration:  1.19 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  59.688 % |total_loss:  62.32369554042816 | epoch_duration:  1.96 sec
# Epoch no. 2 |test accuracy:  88.125 % |total_loss:  18.035461246967316 | epoch_duration:  1.41 sec
# Epoch no. 3 |test accuracy:  93.125 % |total_loss:  4.4359151013195515 | epoch_duration:  1.18 sec
# Epoch no. 4 |test accuracy:  95.938 % |total_loss:  1.6881438833661377 | epoch_duration:  1.17 sec
# Epoch no. 5 |test accuracy:  97.812 % |total_loss:  0.9564247261732817 | epoch_duration:  1.19 sec
# Epoch no. 6 |test accuracy:  92.5 % |total_loss:  1.0974540850729682 | epoch_duration:  1.18 sec
# Epoch no. 7 |test accuracy:  95.0 % |total_loss:  2.032011009287089 | epoch_duration:  1.21 sec
# Epoch no. 8 |test accuracy:  98.438 % |total_loss:  1.2531046401709318 | epoch_duration:  1.18 sec
# Epoch no. 9 |test accuracy:  98.75 % |total_loss:  0.1965585875150282 | epoch_duration:  1.18 sec
# Epoch no. 10 |test accuracy:  98.125 % |total_loss:  0.12349464109865949 | epoch_duration:  1.35 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  64.375 % |total_loss:  61.34104758501053 | epoch_duration:  1.2 sec
# Epoch no. 2 |test accuracy:  82.188 % |total_loss:  26.571571469306946 | epoch_duration:  1.19 sec
# Epoch no. 3 |test accuracy:  90.312 % |total_loss:  10.436014756560326 | epoch_duration:  1.21 sec
# Epoch no. 4 |test accuracy:  94.375 % |total_loss:  7.6482216864824295 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  92.812 % |total_loss:  3.162844719365239 | epoch_duration:  1.2 sec
# Epoch no. 6 |test accuracy:  95.938 % |total_loss:  2.2751352842897177 | epoch_duration:  1.2 sec
# Epoch no. 7 |test accuracy:  95.625 % |total_loss:  3.1970319151878357 | epoch_duration:  1.78 sec
# Epoch no. 8 |test accuracy:  97.812 % |total_loss:  1.7726846653968096 | epoch_duration:  1.68 sec
# Epoch no. 9 |test accuracy:  95.625 % |total_loss:  1.519964030245319 | epoch_duration:  1.23 sec
# Epoch no. 10 |test accuracy:  95.0 % |total_loss:  3.7092032339423895 | epoch_duration:  1.23 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  55.937 % |total_loss:  60.85971415042877 | epoch_duration:  1.2 sec
# Epoch no. 2 |test accuracy:  79.688 % |total_loss:  26.422401934862137 | epoch_duration:  1.23 sec
# Epoch no. 3 |test accuracy:  90.938 % |total_loss:  11.514489844441414 | epoch_duration:  1.19 sec
# Epoch no. 4 |test accuracy:  88.438 % |total_loss:  6.020831577479839 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  92.5 % |total_loss:  5.1804277040064335 | epoch_duration:  1.17 sec
# Epoch no. 6 |test accuracy:  95.625 % |total_loss:  5.28507106564939 | epoch_duration:  1.25 sec
# Epoch no. 7 |test accuracy:  94.688 % |total_loss:  1.9345737090334296 | epoch_duration:  1.91 sec
# Epoch no. 8 |test accuracy:  95.625 % |total_loss:  2.08184752240777 | epoch_duration:  1.38 sec
# Epoch no. 9 |test accuracy:  97.188 % |total_loss:  1.7007632083259523 | epoch_duration:  1.24 sec
# Epoch no. 10 |test accuracy:  94.375 % |total_loss:  2.321479027159512 | epoch_duration:  1.18 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  52.5 % |total_loss:  60.73226714134216 | epoch_duration:  1.22 sec
# Epoch no. 2 |test accuracy:  72.188 % |total_loss:  28.077061712741852 | epoch_duration:  1.19 sec
# Epoch no. 3 |test accuracy:  88.75 % |total_loss:  11.866738125681877 | epoch_duration:  1.18 sec
# Epoch no. 4 |test accuracy:  92.812 % |total_loss:  5.245541475713253 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  95.312 % |total_loss:  3.505300147458911 | epoch_duration:  1.22 sec
# Epoch no. 6 |test accuracy:  91.562 % |total_loss:  3.127677391283214 | epoch_duration:  1.46 sec
# Epoch no. 7 |test accuracy:  96.25 % |total_loss:  2.452978673391044 | epoch_duration:  1.94 sec
# Epoch no. 8 |test accuracy:  91.25 % |total_loss:  2.4492761213332415 | epoch_duration:  1.26 sec
# Epoch no. 9 |test accuracy:  93.125 % |total_loss:  3.020446670241654 | epoch_duration:  1.2 sec
# Epoch no. 10 |test accuracy:  93.75 % |total_loss:  2.585133562795818 | epoch_duration:  1.2 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  12.5 % |total_loss:  73.74818277359009 | epoch_duration:  1.19 sec
# Epoch no. 2 |test accuracy:  34.375 % |total_loss:  64.86248755455017 | epoch_duration:  1.18 sec
# Epoch no. 3 |test accuracy:  50.938 % |total_loss:  48.362966418266296 | epoch_duration:  1.19 sec
# Epoch no. 4 |test accuracy:  59.688 % |total_loss:  35.37618774175644 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  64.375 % |total_loss:  28.904791831970215 | epoch_duration:  1.16 sec
# Epoch no. 6 |test accuracy:  72.812 % |total_loss:  22.60638004541397 | epoch_duration:  1.79 sec
# Epoch no. 7 |test accuracy:  79.688 % |total_loss:  18.148686558008194 | epoch_duration:  1.66 sec
# Epoch no. 8 |test accuracy:  79.375 % |total_loss:  15.326516449451447 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  85.0 % |total_loss:  12.135085314512253 | epoch_duration:  1.21 sec
# Epoch no. 10 |test accuracy:  85.0 % |total_loss:  9.168627440929413 | epoch_duration:  1.22 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  23.75 % |total_loss:  73.78585195541382 | epoch_duration:  1.23 sec
# Epoch no. 2 |test accuracy:  42.5 % |total_loss:  60.893064737319946 | epoch_duration:  1.17 sec
# Epoch no. 3 |test accuracy:  59.062 % |total_loss:  39.59988099336624 | epoch_duration:  1.19 sec
# Epoch no. 4 |test accuracy:  64.688 % |total_loss:  28.79049515724182 | epoch_duration:  1.22 sec
# Epoch no. 5 |test accuracy:  76.562 % |total_loss:  20.249349355697632 | epoch_duration:  1.32 sec
# Epoch no. 6 |test accuracy:  81.25 % |total_loss:  15.399859100580215 | epoch_duration:  1.95 sec
# Epoch no. 7 |test accuracy:  84.062 % |total_loss:  12.229720532894135 | epoch_duration:  1.32 sec
# Epoch no. 8 |test accuracy:  85.0 % |total_loss:  8.660456493496895 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  84.375 % |total_loss:  6.847606346011162 | epoch_duration:  1.21 sec
# Epoch no. 10 |test accuracy:  86.875 % |total_loss:  5.857435271143913 | epoch_duration:  1.22 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  23.125 % |total_loss:  71.82385754585266 | epoch_duration:  1.21 sec
# Epoch no. 2 |test accuracy:  48.75 % |total_loss:  52.173985719680786 | epoch_duration:  1.8 sec
# Epoch no. 3 |test accuracy:  61.562 % |total_loss:  37.881596982479095 | epoch_duration:  1.65 sec
# Epoch no. 4 |test accuracy:  68.438 % |total_loss:  28.749346017837524 | epoch_duration:  1.21 sec
# Epoch no. 5 |test accuracy:  70.938 % |total_loss:  23.616303861141205 | epoch_duration:  1.19 sec
# Epoch no. 6 |test accuracy:  77.188 % |total_loss:  20.85523882508278 | epoch_duration:  1.16 sec
# Epoch no. 7 |test accuracy:  71.875 % |total_loss:  17.62160485982895 | epoch_duration:  1.18 sec
# Epoch no. 8 |test accuracy:  79.062 % |total_loss:  15.917157709598541 | epoch_duration:  1.17 sec
# Epoch no. 9 |test accuracy:  78.125 % |total_loss:  13.795950472354889 | epoch_duration:  1.21 sec
# Epoch no. 10 |test accuracy:  80.312 % |total_loss:  11.35181476175785 | epoch_duration:  1.17 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  67.812 % |total_loss:  55.435245394706726 | epoch_duration:  1.27 sec
# Epoch no. 2 |test accuracy:  81.562 % |total_loss:  19.622820287942886 | epoch_duration:  1.95 sec
# Epoch no. 3 |test accuracy:  89.062 % |total_loss:  9.569198161363602 | epoch_duration:  1.46 sec
# Epoch no. 4 |test accuracy:  91.875 % |total_loss:  5.141531426459551 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  91.875 % |total_loss:  3.734883353114128 | epoch_duration:  1.2 sec
# Epoch no. 6 |test accuracy:  92.812 % |total_loss:  5.421959154307842 | epoch_duration:  1.21 sec
# Epoch no. 7 |test accuracy:  91.875 % |total_loss:  3.2232495825737715 | epoch_duration:  1.19 sec
# Epoch no. 8 |test accuracy:  94.688 % |total_loss:  2.8350465521216393 | epoch_duration:  1.19 sec
# Epoch no. 9 |test accuracy:  95.938 % |total_loss:  1.9199044718407094 | epoch_duration:  1.19 sec
# Epoch no. 10 |test accuracy:  95.0 % |total_loss:  1.5324657750315964 | epoch_duration:  1.22 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  56.563 % |total_loss:  57.21909236907959 | epoch_duration:  1.39 sec
# Epoch no. 2 |test accuracy:  83.75 % |total_loss:  25.466125339269638 | epoch_duration:  1.93 sec
# Epoch no. 3 |test accuracy:  86.875 % |total_loss:  11.214234843850136 | epoch_duration:  1.24 sec
# Epoch no. 4 |test accuracy:  91.562 % |total_loss:  5.187076386064291 | epoch_duration:  1.22 sec
# Epoch no. 5 |test accuracy:  94.375 % |total_loss:  4.424885164946318 | epoch_duration:  1.21 sec
# Epoch no. 6 |test accuracy:  95.312 % |total_loss:  2.552124668844044 | epoch_duration:  1.15 sec
# Epoch no. 7 |test accuracy:  87.812 % |total_loss:  2.343193248845637 | epoch_duration:  1.18 sec
# Epoch no. 8 |test accuracy:  95.625 % |total_loss:  2.6366095254197717 | epoch_duration:  1.25 sec
# Epoch no. 9 |test accuracy:  95.312 % |total_loss:  1.8668203973211348 | epoch_duration:  1.21 sec
# Epoch no. 10 |test accuracy:  92.188 % |total_loss:  4.284849079325795 | epoch_duration:  1.19 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  75.0 % |total_loss:  56.49807780981064 | epoch_duration:  1.73 sec
# Epoch no. 2 |test accuracy:  86.562 % |total_loss:  14.118533909320831 | epoch_duration:  1.72 sec
# Epoch no. 3 |test accuracy:  94.375 % |total_loss:  5.304586589336395 | epoch_duration:  1.2 sec
# Epoch no. 4 |test accuracy:  94.062 % |total_loss:  2.795920806005597 | epoch_duration:  1.22 sec
# Epoch no. 5 |test accuracy:  95.625 % |total_loss:  2.3169560888782144 | epoch_duration:  1.21 sec
# Epoch no. 6 |test accuracy:  95.625 % |total_loss:  1.8896654557902366 | epoch_duration:  1.21 sec
# Epoch no. 7 |test accuracy:  93.125 % |total_loss:  1.8243288453668356 | epoch_duration:  1.18 sec
# Epoch no. 8 |test accuracy:  95.0 % |total_loss:  1.5011875261552632 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  95.0 % |total_loss:  0.9898282886715606 | epoch_duration:  1.19 sec
# Epoch no. 10 |test accuracy:  97.812 % |total_loss:  1.6215552825015038 | epoch_duration:  1.22 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  74.09753680229187 | epoch_duration:  1.97 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  73.73326587677002 | epoch_duration:  1.43 sec
# Epoch no. 3 |test accuracy:  10.0 % |total_loss:  73.72890019416809 | epoch_duration:  1.22 sec
# Epoch no. 4 |test accuracy:  10.0 % |total_loss:  73.71449518203735 | epoch_duration:  1.17 sec
# Epoch no. 5 |test accuracy:  10.0 % |total_loss:  73.7351245880127 | epoch_duration:  1.2 sec
# Epoch no. 6 |test accuracy:  10.0 % |total_loss:  73.7156298160553 | epoch_duration:  1.21 sec
# Epoch no. 7 |test accuracy:  10.0 % |total_loss:  73.72406601905823 | epoch_duration:  1.19 sec
# Epoch no. 8 |test accuracy:  10.0 % |total_loss:  73.7107400894165 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  10.0 % |total_loss:  73.70903420448303 | epoch_duration:  1.21 sec
# Epoch no. 10 |test accuracy:  10.0 % |total_loss:  73.72183561325073 | epoch_duration:  1.36 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  27.812 % |total_loss:  72.31728768348694 | epoch_duration:  1.22 sec
# Epoch no. 2 |test accuracy:  35.938 % |total_loss:  57.105430483818054 | epoch_duration:  1.2 sec
# Epoch no. 3 |test accuracy:  55.0 % |total_loss:  41.120859146118164 | epoch_duration:  1.2 sec
# Epoch no. 4 |test accuracy:  58.125 % |total_loss:  30.821480989456177 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  65.938 % |total_loss:  26.944727420806885 | epoch_duration:  1.2 sec
# Epoch no. 6 |test accuracy:  69.375 % |total_loss:  21.6695576608181 | epoch_duration:  1.2 sec
# Epoch no. 7 |test accuracy:  71.25 % |total_loss:  17.622595369815826 | epoch_duration:  1.9 sec
# Epoch no. 8 |test accuracy:  72.5 % |total_loss:  18.205924481153488 | epoch_duration:  1.62 sec
# Epoch no. 9 |test accuracy:  74.688 % |total_loss:  15.53898537158966 | epoch_duration:  1.23 sec
# Epoch no. 10 |test accuracy:  75.625 % |total_loss:  13.28852079808712 | epoch_duration:  1.23 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  64.062 % |total_loss:  60.104647278785706 | epoch_duration:  1.2 sec
# Epoch no. 2 |test accuracy:  84.375 % |total_loss:  26.53479877114296 | epoch_duration:  1.2 sec
# Epoch no. 3 |test accuracy:  86.562 % |total_loss:  11.757191881537437 | epoch_duration:  1.24 sec
# Epoch no. 4 |test accuracy:  88.438 % |total_loss:  7.593025974929333 | epoch_duration:  1.24 sec
# Epoch no. 5 |test accuracy:  89.062 % |total_loss:  6.517813503742218 | epoch_duration:  1.21 sec
# Epoch no. 6 |test accuracy:  93.125 % |total_loss:  4.930093230679631 | epoch_duration:  1.39 sec
# Epoch no. 7 |test accuracy:  91.875 % |total_loss:  3.456847818568349 | epoch_duration:  1.99 sec
# Epoch no. 8 |test accuracy:  90.938 % |total_loss:  2.4075377881526947 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  94.688 % |total_loss:  1.8157047042623162 | epoch_duration:  1.23 sec
# Epoch no. 10 |test accuracy:  95.312 % |total_loss:  1.064293896779418 | epoch_duration:  1.2 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  10.0 % |total_loss:  73.90754127502441 | epoch_duration:  1.24 sec
# Epoch no. 2 |test accuracy:  10.0 % |total_loss:  73.74781489372253 | epoch_duration:  1.23 sec
# Epoch no. 3 |test accuracy:  10.0 % |total_loss:  73.71938347816467 | epoch_duration:  1.22 sec
# Epoch no. 4 |test accuracy:  10.0 % |total_loss:  73.71200823783875 | epoch_duration:  1.21 sec
# Epoch no. 5 |test accuracy:  10.0 % |total_loss:  73.71711039543152 | epoch_duration:  1.25 sec
# Epoch no. 6 |test accuracy:  10.0 % |total_loss:  73.70601677894592 | epoch_duration:  1.88 sec
# Epoch no. 7 |test accuracy:  10.0 % |total_loss:  73.70928144454956 | epoch_duration:  1.62 sec
# Epoch no. 8 |test accuracy:  10.0 % |total_loss:  73.71555495262146 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  10.0 % |total_loss:  73.7087390422821 | epoch_duration:  1.19 sec
# Epoch no. 10 |test accuracy:  10.0 % |total_loss:  73.70643472671509 | epoch_duration:  1.22 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  52.188 % |total_loss:  63.00301945209503 | epoch_duration:  1.21 sec
# Epoch no. 2 |test accuracy:  77.812 % |total_loss:  27.18829196691513 | epoch_duration:  1.22 sec
# Epoch no. 3 |test accuracy:  82.188 % |total_loss:  12.583491742610931 | epoch_duration:  1.2 sec
# Epoch no. 4 |test accuracy:  92.812 % |total_loss:  8.066806703805923 | epoch_duration:  1.21 sec
# Epoch no. 5 |test accuracy:  91.562 % |total_loss:  4.144914427772164 | epoch_duration:  1.37 sec
# Epoch no. 6 |test accuracy:  90.312 % |total_loss:  2.208888104185462 | epoch_duration:  1.98 sec
# Epoch no. 7 |test accuracy:  86.875 % |total_loss:  3.5405985834077 | epoch_duration:  1.28 sec
# Epoch no. 8 |test accuracy:  94.375 % |total_loss:  2.50605723913759 | epoch_duration:  1.21 sec
# Epoch no. 9 |test accuracy:  91.875 % |total_loss:  2.3514078008010983 | epoch_duration:  1.22 sec
# Epoch no. 10 |test accuracy:  90.625 % |total_loss:  3.1898143887519836 | epoch_duration:  1.23 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  58.125 % |total_loss:  60.46809458732605 | epoch_duration:  1.22 sec
# Epoch no. 2 |test accuracy:  78.438 % |total_loss:  25.191867619752884 | epoch_duration:  1.22 sec
# Epoch no. 3 |test accuracy:  87.188 % |total_loss:  12.762626573443413 | epoch_duration:  1.19 sec
# Epoch no. 4 |test accuracy:  87.188 % |total_loss:  6.744938537478447 | epoch_duration:  1.18 sec
# Epoch no. 5 |test accuracy:  90.312 % |total_loss:  3.6460964120924473 | epoch_duration:  1.74 sec
# Epoch no. 6 |test accuracy:  90.0 % |total_loss:  2.9757209867239 | epoch_duration:  1.72 sec
# Epoch no. 7 |test accuracy:  92.5 % |total_loss:  4.001349780708551 | epoch_duration:  1.22 sec
# Epoch no. 8 |test accuracy:  95.625 % |total_loss:  2.114960139617324 | epoch_duration:  1.19 sec
# Epoch no. 9 |test accuracy:  92.812 % |total_loss:  2.5336029725149274 | epoch_duration:  1.18 sec
# Epoch no. 10 |test accuracy:  93.125 % |total_loss:  2.5105489483103156 | epoch_duration:  1.22 sec

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

epochs = [i for i in range(10)]
 
for i in range(len(k_list)):
  plt.plot(epochs, np.mean(np.asarray(seed_image_experiment_1)[i,:,:], axis=0), label=str(k_list[i]))

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("MNIST - Modified LeNet")
plt.legend(title = 'k')

# %% [markdown]
# ### Simple Convnet

# %%
class Network(nn.Module): # extend nn.Module class of nn
    def __init__(self):
        super().__init__() # super class constructor
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(5,5))
        self.fc = nn.Linear(in_features=6*35*35, out_features=10)
        
    def forward(self, t): # implements the forward method (flow of tensors)
        
        # hidden conv layer 
        t = self.conv1(t) 
        t = F.relu(t)
        
        t = t.reshape(-1, 6*35*35)
        t = self.fc(t)
        
        return t

# %%
n = 320
k_list = [1, 2, 4, 8, 16, 32]
n_classes = 10

seed_image_experiment_2 = []
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for k in k_list:
  
  accuracies = []
  seed_images, classes = get_seed_images(k=k)

  for j in range(5):
    accuracy_epoch = []    
    print(f"Number of seed_images = {k}")
    dataset_images = torch.zeros(n*n_classes,1,39,39) 
    dataset_labels = einops.repeat(torch.tensor(classes), 'n -> (repeat n)', repeat=n//k)

    for i in range(n//k):
      new_images = augment(device, seed_images)
      dataset_images[n_classes*k*i:n_classes*k*i+n_classes*k] = new_images


    dataset = Augmented_Dataset(dataset_images, dataset_labels)

    train_idx, validation_idx = train_test_split(np.arange(len(dataset)),
                                                test_size=0.1,
                                                random_state=999,
                                                shuffle=True,
                                                stratify=dataset.labels)

    train_dataset = Subset(dataset, train_idx)
    validation_dataset = Subset(dataset, validation_idx)

    cnn_model = Network().to(device) # init model

    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=90, shuffle=True, num_workers=1)
    test_dataloader = torch.utils.data.DataLoader(validation_dataset, batch_size=10, shuffle=False, num_workers=1)

    optimizer = optim.Adam(lr=0.01, params=cnn_model.parameters())
    # def train loop
    def get_item(preds, labels):
        """function that returns the accuracy of our architecture"""
        return preds.argmax(dim=1).eq(labels).sum().item()

    for epoch in range(10):
        start_time = time.time()
        total_correct = 0
        total_loss = 0
        for batch in train_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs) # get preds
            loss = F.cross_entropy(preds, lbls) # compute loss
            optimizer.zero_grad() # zero grads
            loss.backward() # calculates gradients 
            optimizer.step() # update the weights
            total_loss += loss.item()
        
        for batch in test_dataloader:
            imgs, lbls = batch
            imgs, lbls = imgs.to(device), lbls.to(device)
            preds = cnn_model(imgs)
            total_correct += get_item(preds, lbls)
            accuracy = total_correct/len(validation_dataset)

        accuracy_epoch.append(accuracy)
        end_time = time.time() - start_time    
        print("Epoch no.",epoch+1 ,"|test accuracy: ", round(accuracy*100, 3),"%", "|total_loss: ", total_loss, "| epoch_duration: ", round(end_time,2),"sec")

    accuracies.append(accuracy_epoch)
  seed_image_experiment_2.append(accuracies)
# Out:
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  77.5 % |total_loss:  98.26058745384216 | epoch_duration:  0.75 sec
# Epoch no. 2 |test accuracy:  98.125 % |total_loss:  9.033144019544125 | epoch_duration:  2.04 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  1.128865985199809 | epoch_duration:  2.09 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.22853231383487582 | epoch_duration:  1.53 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.08941920602228492 | epoch_duration:  0.72 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.061899399384856224 | epoch_duration:  0.74 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.04838970862329006 | epoch_duration:  0.73 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.03911938314558938 | epoch_duration:  0.75 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.03255322476616129 | epoch_duration:  0.73 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.027366386260837317 | epoch_duration:  0.75 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  80.312 % |total_loss:  83.139513194561 | epoch_duration:  0.76 sec
# Epoch no. 2 |test accuracy:  99.375 % |total_loss:  7.058529391884804 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  99.375 % |total_loss:  0.4771191501058638 | epoch_duration:  0.75 sec
# Epoch no. 4 |test accuracy:  99.375 % |total_loss:  0.09602819883730263 | epoch_duration:  0.78 sec
# Epoch no. 5 |test accuracy:  99.688 % |total_loss:  0.052532432484440506 | epoch_duration:  1.18 sec
# Epoch no. 6 |test accuracy:  99.688 % |total_loss:  0.037885130499489605 | epoch_duration:  1.26 sec
# Epoch no. 7 |test accuracy:  99.688 % |total_loss:  0.029859877249691635 | epoch_duration:  0.96 sec
# Epoch no. 8 |test accuracy:  99.688 % |total_loss:  0.02434001473011449 | epoch_duration:  0.76 sec
# Epoch no. 9 |test accuracy:  99.688 % |total_loss:  0.020421356428414583 | epoch_duration:  0.84 sec
# Epoch no. 10 |test accuracy:  99.688 % |total_loss:  0.017432704160455614 | epoch_duration:  0.75 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  56.563 % |total_loss:  108.333336353302 | epoch_duration:  0.75 sec
# Epoch no. 2 |test accuracy:  94.688 % |total_loss:  18.69362063705921 | epoch_duration:  0.76 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  1.4008550089783967 | epoch_duration:  0.75 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.15915539301931858 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.0660516805946827 | epoch_duration:  0.73 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.046598062152042985 | epoch_duration:  0.76 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.03689419972943142 | epoch_duration:  0.72 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.030266306654084474 | epoch_duration:  0.76 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.02544842171482742 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.02176363707985729 | epoch_duration:  1.01 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  84.375 % |total_loss:  56.921579509973526 | epoch_duration:  1.27 sec
# Epoch no. 2 |test accuracy:  98.75 % |total_loss:  4.79404978454113 | epoch_duration:  0.92 sec
# Epoch no. 3 |test accuracy:  99.688 % |total_loss:  0.4044465543702245 | epoch_duration:  0.71 sec
# Epoch no. 4 |test accuracy:  99.688 % |total_loss:  0.08257884514750913 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  99.688 % |total_loss:  0.03733121731784195 | epoch_duration:  0.76 sec
# Epoch no. 6 |test accuracy:  99.688 % |total_loss:  0.026165026472881436 | epoch_duration:  0.77 sec
# Epoch no. 7 |test accuracy:  99.688 % |total_loss:  0.020598660048563033 | epoch_duration:  0.75 sec
# Epoch no. 8 |test accuracy:  99.688 % |total_loss:  0.01698487877729349 | epoch_duration:  0.77 sec
# Epoch no. 9 |test accuracy:  99.688 % |total_loss:  0.014242724777432159 | epoch_duration:  0.77 sec
# Epoch no. 10 |test accuracy:  99.688 % |total_loss:  0.012178986798971891 | epoch_duration:  0.74 sec
# Number of seed_images = 1
# Epoch no. 1 |test accuracy:  82.812 % |total_loss:  100.67677795886993 | epoch_duration:  0.73 sec
# Epoch no. 2 |test accuracy:  98.438 % |total_loss:  7.532792165875435 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  100.0 % |total_loss:  0.5661594998091459 | epoch_duration:  0.73 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.10628839721903205 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.051037515862844884 | epoch_duration:  0.93 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.03743667062371969 | epoch_duration:  1.28 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.02989640214946121 | epoch_duration:  1.12 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.024601420300314203 | epoch_duration:  0.72 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.02062511068652384 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.017614191689062864 | epoch_duration:  0.76 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  64.062 % |total_loss:  85.67927861213684 | epoch_duration:  0.73 sec
# Epoch no. 2 |test accuracy:  93.75 % |total_loss:  12.90195331722498 | epoch_duration:  0.76 sec
# Epoch no. 3 |test accuracy:  99.375 % |total_loss:  1.154452694579959 | epoch_duration:  0.75 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.2576845159055665 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  99.688 % |total_loss:  0.07856722379801795 | epoch_duration:  0.83 sec
# Epoch no. 6 |test accuracy:  99.688 % |total_loss:  0.03633747500134632 | epoch_duration:  1.27 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.025866920419503003 | epoch_duration:  1.21 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.021170724183321 | epoch_duration:  0.73 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.01782268498209305 | epoch_duration:  0.73 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.015403205034090206 | epoch_duration:  0.75 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  78.125 % |total_loss:  67.78025299310684 | epoch_duration:  0.74 sec
# Epoch no. 2 |test accuracy:  96.25 % |total_loss:  7.821375370025635 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  98.125 % |total_loss:  1.113390932790935 | epoch_duration:  0.72 sec
# Epoch no. 4 |test accuracy:  99.062 % |total_loss:  0.4570953727234155 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  99.375 % |total_loss:  0.08599864575080574 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  99.375 % |total_loss:  0.030491899291519076 | epoch_duration:  0.74 sec
# Epoch no. 7 |test accuracy:  99.375 % |total_loss:  0.020301763608586043 | epoch_duration:  0.73 sec
# Epoch no. 8 |test accuracy:  99.688 % |total_loss:  0.015976535330992192 | epoch_duration:  0.75 sec
# Epoch no. 9 |test accuracy:  99.688 % |total_loss:  0.013347140367841348 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  99.688 % |total_loss:  0.01131557859480381 | epoch_duration:  0.74 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  47.812 % |total_loss:  121.86978793144226 | epoch_duration:  1.26 sec
# Epoch no. 2 |test accuracy:  92.188 % |total_loss:  19.529789194464684 | epoch_duration:  1.27 sec
# Epoch no. 3 |test accuracy:  98.75 % |total_loss:  2.3066441249102354 | epoch_duration:  0.78 sec
# Epoch no. 4 |test accuracy:  100.0 % |total_loss:  0.3874967326410115 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  100.0 % |total_loss:  0.15189824532717466 | epoch_duration:  0.74 sec
# Epoch no. 6 |test accuracy:  100.0 % |total_loss:  0.09219550457783043 | epoch_duration:  0.74 sec
# Epoch no. 7 |test accuracy:  100.0 % |total_loss:  0.06964492821134627 | epoch_duration:  0.75 sec
# Epoch no. 8 |test accuracy:  100.0 % |total_loss:  0.0549560678191483 | epoch_duration:  0.74 sec
# Epoch no. 9 |test accuracy:  100.0 % |total_loss:  0.044779168674722314 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  100.0 % |total_loss:  0.037716246966738254 | epoch_duration:  0.74 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  46.562 % |total_loss:  101.56098651885986 | epoch_duration:  0.76 sec
# Epoch no. 2 |test accuracy:  88.75 % |total_loss:  22.112736761569977 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  99.062 % |total_loss:  2.64577616751194 | epoch_duration:  0.74 sec
# Epoch no. 4 |test accuracy:  99.688 % |total_loss:  0.37856358429417014 | epoch_duration:  0.73 sec
# Epoch no. 5 |test accuracy:  99.688 % |total_loss:  0.12570794043131173 | epoch_duration:  0.82 sec
# Epoch no. 6 |test accuracy:  99.688 % |total_loss:  0.07206794549711049 | epoch_duration:  2.54 sec
# Epoch no. 7 |test accuracy:  99.688 % |total_loss:  0.05241468723397702 | epoch_duration:  1.56 sec
# Epoch no. 8 |test accuracy:  99.688 % |total_loss:  0.04159490024903789 | epoch_duration:  0.75 sec
# Epoch no. 9 |test accuracy:  99.688 % |total_loss:  0.03438755148090422 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  99.688 % |total_loss:  0.028755146195180714 | epoch_duration:  0.74 sec
# Number of seed_images = 2
# Epoch no. 1 |test accuracy:  55.937 % |total_loss:  102.91479778289795 | epoch_duration:  0.75 sec
# Epoch no. 2 |test accuracy:  89.688 % |total_loss:  18.06947885453701 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  95.0 % |total_loss:  2.263089921325445 | epoch_duration:  0.73 sec
# Epoch no. 4 |test accuracy:  98.125 % |total_loss:  0.5652467114850879 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  98.75 % |total_loss:  0.14468626445159316 | epoch_duration:  0.77 sec
# Epoch no. 6 |test accuracy:  98.75 % |total_loss:  0.06788172526285052 | epoch_duration:  0.78 sec
# Epoch no. 7 |test accuracy:  98.75 % |total_loss:  0.04736130533274263 | epoch_duration:  0.74 sec
# Epoch no. 8 |test accuracy:  98.75 % |total_loss:  0.03768187289824709 | epoch_duration:  0.74 sec
# Epoch no. 9 |test accuracy:  98.75 % |total_loss:  0.03099788265535608 | epoch_duration:  0.73 sec
# Epoch no. 10 |test accuracy:  99.062 % |total_loss:  0.02598512696567923 | epoch_duration:  1.01 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  48.438 % |total_loss:  97.86317825317383 | epoch_duration:  0.77 sec
# Epoch no. 2 |test accuracy:  85.938 % |total_loss:  24.7054383456707 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  95.0 % |total_loss:  4.71464553847909 | epoch_duration:  0.74 sec
# Epoch no. 4 |test accuracy:  96.25 % |total_loss:  0.9005108214914799 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  97.188 % |total_loss:  0.2724158321507275 | epoch_duration:  0.74 sec
# Epoch no. 6 |test accuracy:  97.188 % |total_loss:  0.12719084741547704 | epoch_duration:  0.77 sec
# Epoch no. 7 |test accuracy:  97.5 % |total_loss:  0.08355704846326262 | epoch_duration:  0.76 sec
# Epoch no. 8 |test accuracy:  96.562 % |total_loss:  0.06312230427283794 | epoch_duration:  1.31 sec
# Epoch no. 9 |test accuracy:  97.188 % |total_loss:  0.05166381306480616 | epoch_duration:  1.28 sec
# Epoch no. 10 |test accuracy:  97.188 % |total_loss:  0.04425539809744805 | epoch_duration:  0.78 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  43.75 % |total_loss:  75.72953259944916 | epoch_duration:  0.74 sec
# Epoch no. 2 |test accuracy:  74.688 % |total_loss:  28.59358862042427 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  80.312 % |total_loss:  7.278021603822708 | epoch_duration:  0.76 sec
# Epoch no. 4 |test accuracy:  84.375 % |total_loss:  2.1314935479313135 | epoch_duration:  0.77 sec
# Epoch no. 5 |test accuracy:  87.812 % |total_loss:  0.870140986982733 | epoch_duration:  0.77 sec
# Epoch no. 6 |test accuracy:  89.375 % |total_loss:  0.28749423916451633 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  90.938 % |total_loss:  0.09977044572588056 | epoch_duration:  0.78 sec
# Epoch no. 8 |test accuracy:  92.188 % |total_loss:  0.04950510466005653 | epoch_duration:  0.74 sec
# Epoch no. 9 |test accuracy:  93.125 % |total_loss:  0.03464358689961955 | epoch_duration:  0.75 sec
# Epoch no. 10 |test accuracy:  93.125 % |total_loss:  0.02788227121345699 | epoch_duration:  0.74 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  58.438 % |total_loss:  82.10222578048706 | epoch_duration:  0.74 sec
# Epoch no. 2 |test accuracy:  82.188 % |total_loss:  18.066686034202576 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  90.0 % |total_loss:  4.5250832960009575 | epoch_duration:  1.23 sec
# Epoch no. 4 |test accuracy:  92.188 % |total_loss:  1.2008583080023527 | epoch_duration:  1.24 sec
# Epoch no. 5 |test accuracy:  92.188 % |total_loss:  0.43701190035790205 | epoch_duration:  0.86 sec
# Epoch no. 6 |test accuracy:  92.812 % |total_loss:  0.15245237201452255 | epoch_duration:  0.77 sec
# Epoch no. 7 |test accuracy:  93.125 % |total_loss:  0.08718784572556615 | epoch_duration:  0.72 sec
# Epoch no. 8 |test accuracy:  93.438 % |total_loss:  0.06458865571767092 | epoch_duration:  0.74 sec
# Epoch no. 9 |test accuracy:  93.438 % |total_loss:  0.05275425629224628 | epoch_duration:  0.77 sec
# Epoch no. 10 |test accuracy:  93.125 % |total_loss:  0.044264808064326644 | epoch_duration:  0.79 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  38.75 % |total_loss:  115.9236478805542 | epoch_duration:  0.81 sec
# Epoch no. 2 |test accuracy:  73.75 % |total_loss:  35.370346665382385 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  88.438 % |total_loss:  9.797683224081993 | epoch_duration:  0.74 sec
# Epoch no. 4 |test accuracy:  91.25 % |total_loss:  2.33557965233922 | epoch_duration:  0.77 sec
# Epoch no. 5 |test accuracy:  93.438 % |total_loss:  0.6545111164450645 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  95.312 % |total_loss:  0.28758340841159225 | epoch_duration:  0.73 sec
# Epoch no. 7 |test accuracy:  95.312 % |total_loss:  0.15857356158085167 | epoch_duration:  0.76 sec
# Epoch no. 8 |test accuracy:  95.625 % |total_loss:  0.10581173398531973 | epoch_duration:  1.13 sec
# Epoch no. 9 |test accuracy:  95.625 % |total_loss:  0.07795469427946955 | epoch_duration:  1.29 sec
# Epoch no. 10 |test accuracy:  95.625 % |total_loss:  0.06383005285169929 | epoch_duration:  0.94 sec
# Number of seed_images = 4
# Epoch no. 1 |test accuracy:  55.937 % |total_loss:  105.32840752601624 | epoch_duration:  0.76 sec
# Epoch no. 2 |test accuracy:  77.188 % |total_loss:  22.388064563274384 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  85.938 % |total_loss:  7.391964055597782 | epoch_duration:  0.76 sec
# Epoch no. 4 |test accuracy:  89.688 % |total_loss:  2.3264264091849327 | epoch_duration:  0.75 sec
# Epoch no. 5 |test accuracy:  91.25 % |total_loss:  0.8569819899275899 | epoch_duration:  0.79 sec
# Epoch no. 6 |test accuracy:  92.5 % |total_loss:  0.3201957535929978 | epoch_duration:  0.74 sec
# Epoch no. 7 |test accuracy:  92.188 % |total_loss:  0.13952280534431338 | epoch_duration:  0.76 sec
# Epoch no. 8 |test accuracy:  92.188 % |total_loss:  0.09844406321644783 | epoch_duration:  0.76 sec
# Epoch no. 9 |test accuracy:  92.188 % |total_loss:  0.07279632717836648 | epoch_duration:  0.76 sec
# Epoch no. 10 |test accuracy:  91.562 % |total_loss:  0.05939612339716405 | epoch_duration:  0.76 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  21.875 % |total_loss:  130.87959170341492 | epoch_duration:  0.77 sec
# Epoch no. 2 |test accuracy:  52.5 % |total_loss:  56.69018590450287 | epoch_duration:  0.76 sec
# Epoch no. 3 |test accuracy:  66.25 % |total_loss:  28.462210536003113 | epoch_duration:  0.75 sec
# Epoch no. 4 |test accuracy:  69.062 % |total_loss:  14.431222170591354 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  75.938 % |total_loss:  7.874792695045471 | epoch_duration:  0.78 sec
# Epoch no. 6 |test accuracy:  79.375 % |total_loss:  4.049421265721321 | epoch_duration:  0.77 sec
# Epoch no. 7 |test accuracy:  80.625 % |total_loss:  2.4384802505373955 | epoch_duration:  0.77 sec
# Epoch no. 8 |test accuracy:  81.562 % |total_loss:  1.3871768862009048 | epoch_duration:  0.73 sec
# Epoch no. 9 |test accuracy:  82.188 % |total_loss:  0.7057492472231388 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  82.812 % |total_loss:  0.2980762654915452 | epoch_duration:  0.76 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  24.688 % |total_loss:  127.84430265426636 | epoch_duration:  0.8 sec
# Epoch no. 2 |test accuracy:  48.75 % |total_loss:  53.163524746894836 | epoch_duration:  0.77 sec
# Epoch no. 3 |test accuracy:  60.625 % |total_loss:  29.72531819343567 | epoch_duration:  0.9 sec
# Epoch no. 4 |test accuracy:  68.75 % |total_loss:  17.15094131231308 | epoch_duration:  1.27 sec
# Epoch no. 5 |test accuracy:  71.875 % |total_loss:  8.086964875459671 | epoch_duration:  1.14 sec
# Epoch no. 6 |test accuracy:  75.625 % |total_loss:  4.041507065296173 | epoch_duration:  0.74 sec
# Epoch no. 7 |test accuracy:  75.0 % |total_loss:  1.9603989981114864 | epoch_duration:  0.77 sec
# Epoch no. 8 |test accuracy:  74.688 % |total_loss:  0.9165469175204635 | epoch_duration:  0.78 sec
# Epoch no. 9 |test accuracy:  76.562 % |total_loss:  0.4847975429147482 | epoch_duration:  0.77 sec
# Epoch no. 10 |test accuracy:  75.312 % |total_loss:  0.273975710850209 | epoch_duration:  0.74 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  45.312 % |total_loss:  93.9011743068695 | epoch_duration:  0.74 sec
# Epoch no. 2 |test accuracy:  64.062 % |total_loss:  33.6805254817009 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  70.312 % |total_loss:  15.352660328149796 | epoch_duration:  0.77 sec
# Epoch no. 4 |test accuracy:  77.5 % |total_loss:  6.432543538510799 | epoch_duration:  0.75 sec
# Epoch no. 5 |test accuracy:  81.875 % |total_loss:  2.9178579710423946 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  82.5 % |total_loss:  1.3241428639739752 | epoch_duration:  0.73 sec
# Epoch no. 7 |test accuracy:  81.875 % |total_loss:  0.7481172289699316 | epoch_duration:  0.76 sec
# Epoch no. 8 |test accuracy:  84.062 % |total_loss:  0.39220418501645327 | epoch_duration:  0.8 sec
# Epoch no. 9 |test accuracy:  83.438 % |total_loss:  0.20990211656317115 | epoch_duration:  1.26 sec
# Epoch no. 10 |test accuracy:  84.375 % |total_loss:  0.1366548736114055 | epoch_duration:  1.28 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  41.875 % |total_loss:  110.16282033920288 | epoch_duration:  0.76 sec
# Epoch no. 2 |test accuracy:  73.125 % |total_loss:  33.197160840034485 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  80.625 % |total_loss:  13.517150402069092 | epoch_duration:  0.76 sec
# Epoch no. 4 |test accuracy:  82.5 % |total_loss:  6.675579778850079 | epoch_duration:  0.75 sec
# Epoch no. 5 |test accuracy:  85.938 % |total_loss:  2.7728046979755163 | epoch_duration:  0.74 sec
# Epoch no. 6 |test accuracy:  83.75 % |total_loss:  2.4489742517471313 | epoch_duration:  0.76 sec
# Epoch no. 7 |test accuracy:  88.125 % |total_loss:  1.3499803626909852 | epoch_duration:  0.79 sec
# Epoch no. 8 |test accuracy:  87.5 % |total_loss:  0.5583641836419702 | epoch_duration:  0.73 sec
# Epoch no. 9 |test accuracy:  88.75 % |total_loss:  0.2677276819013059 | epoch_duration:  0.78 sec
# Epoch no. 10 |test accuracy:  88.438 % |total_loss:  0.11957303085364401 | epoch_duration:  0.72 sec
# Number of seed_images = 8
# Epoch no. 1 |test accuracy:  32.812 % |total_loss:  113.17218708992004 | epoch_duration:  0.78 sec
# Epoch no. 2 |test accuracy:  66.562 % |total_loss:  41.3759491443634 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  74.062 % |total_loss:  18.175046026706696 | epoch_duration:  0.76 sec
# Epoch no. 4 |test accuracy:  81.562 % |total_loss:  8.563662379980087 | epoch_duration:  2.07 sec
# Epoch no. 5 |test accuracy:  83.75 % |total_loss:  3.9698194712400436 | epoch_duration:  1.08 sec
# Epoch no. 6 |test accuracy:  84.688 % |total_loss:  1.9078231770545244 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  84.688 % |total_loss:  0.8539431151002645 | epoch_duration:  0.79 sec
# Epoch no. 8 |test accuracy:  85.0 % |total_loss:  0.5963781448081136 | epoch_duration:  0.77 sec
# Epoch no. 9 |test accuracy:  85.625 % |total_loss:  0.32263962738215923 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  86.562 % |total_loss:  0.1781200240366161 | epoch_duration:  0.75 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  23.438 % |total_loss:  162.12313032150269 | epoch_duration:  0.76 sec
# Epoch no. 2 |test accuracy:  58.438 % |total_loss:  47.16094517707825 | epoch_duration:  0.81 sec
# Epoch no. 3 |test accuracy:  70.625 % |total_loss:  25.07006746530533 | epoch_duration:  1.05 sec
# Epoch no. 4 |test accuracy:  72.812 % |total_loss:  14.069655537605286 | epoch_duration:  1.27 sec
# Epoch no. 5 |test accuracy:  75.312 % |total_loss:  8.67632408440113 | epoch_duration:  1.04 sec
# Epoch no. 6 |test accuracy:  76.25 % |total_loss:  4.143910698592663 | epoch_duration:  0.77 sec
# Epoch no. 7 |test accuracy:  77.188 % |total_loss:  2.25298198312521 | epoch_duration:  0.74 sec
# Epoch no. 8 |test accuracy:  78.125 % |total_loss:  1.330774150788784 | epoch_duration:  0.74 sec
# Epoch no. 9 |test accuracy:  79.375 % |total_loss:  1.017909947782755 | epoch_duration:  0.74 sec
# Epoch no. 10 |test accuracy:  79.062 % |total_loss:  0.9488707985728979 | epoch_duration:  0.77 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  42.188 % |total_loss:  90.67914772033691 | epoch_duration:  0.74 sec
# Epoch no. 2 |test accuracy:  73.125 % |total_loss:  34.11828210949898 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  73.125 % |total_loss:  14.087898761034012 | epoch_duration:  0.74 sec
# Epoch no. 4 |test accuracy:  75.625 % |total_loss:  6.124442100524902 | epoch_duration:  0.8 sec
# Epoch no. 5 |test accuracy:  75.0 % |total_loss:  3.521607793867588 | epoch_duration:  0.78 sec
# Epoch no. 6 |test accuracy:  76.25 % |total_loss:  1.3460396863520145 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  77.188 % |total_loss:  0.6063700071536005 | epoch_duration:  0.74 sec
# Epoch no. 8 |test accuracy:  78.125 % |total_loss:  0.22676422796212137 | epoch_duration:  0.89 sec
# Epoch no. 9 |test accuracy:  78.438 % |total_loss:  0.11516256583854556 | epoch_duration:  1.28 sec
# Epoch no. 10 |test accuracy:  78.125 % |total_loss:  0.07891251042019576 | epoch_duration:  1.18 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  26.25 % |total_loss:  114.24246835708618 | epoch_duration:  0.76 sec
# Epoch no. 2 |test accuracy:  66.562 % |total_loss:  43.50952064990997 | epoch_duration:  0.76 sec
# Epoch no. 3 |test accuracy:  69.062 % |total_loss:  18.290781140327454 | epoch_duration:  0.74 sec
# Epoch no. 4 |test accuracy:  75.312 % |total_loss:  8.966425269842148 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  77.5 % |total_loss:  3.884612515568733 | epoch_duration:  0.77 sec
# Epoch no. 6 |test accuracy:  77.812 % |total_loss:  1.904604572802782 | epoch_duration:  0.77 sec
# Epoch no. 7 |test accuracy:  77.812 % |total_loss:  1.075735280290246 | epoch_duration:  0.75 sec
# Epoch no. 8 |test accuracy:  75.0 % |total_loss:  0.961444572545588 | epoch_duration:  0.77 sec
# Epoch no. 9 |test accuracy:  76.562 % |total_loss:  0.5533624161034822 | epoch_duration:  0.76 sec
# Epoch no. 10 |test accuracy:  76.875 % |total_loss:  0.25741857825778425 | epoch_duration:  0.76 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  47.188 % |total_loss:  123.20193982124329 | epoch_duration:  0.75 sec
# Epoch no. 2 |test accuracy:  69.688 % |total_loss:  33.09713417291641 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  75.938 % |total_loss:  16.261214196681976 | epoch_duration:  0.95 sec
# Epoch no. 4 |test accuracy:  79.688 % |total_loss:  9.017732754349709 | epoch_duration:  1.3 sec
# Epoch no. 5 |test accuracy:  81.875 % |total_loss:  4.46332474052906 | epoch_duration:  1.16 sec
# Epoch no. 6 |test accuracy:  79.375 % |total_loss:  2.435283575206995 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  83.438 % |total_loss:  1.3019366264343262 | epoch_duration:  0.74 sec
# Epoch no. 8 |test accuracy:  84.375 % |total_loss:  0.7624171823263168 | epoch_duration:  0.78 sec
# Epoch no. 9 |test accuracy:  83.438 % |total_loss:  0.36346410773694515 | epoch_duration:  0.76 sec
# Epoch no. 10 |test accuracy:  83.438 % |total_loss:  0.20213453844189644 | epoch_duration:  0.74 sec
# Number of seed_images = 16
# Epoch no. 1 |test accuracy:  40.0 % |total_loss:  118.93162369728088 | epoch_duration:  0.75 sec
# Epoch no. 2 |test accuracy:  62.813 % |total_loss:  39.319986402988434 | epoch_duration:  0.75 sec
# Epoch no. 3 |test accuracy:  71.25 % |total_loss:  19.84049117565155 | epoch_duration:  0.74 sec
# Epoch no. 4 |test accuracy:  76.25 % |total_loss:  9.441100969910622 | epoch_duration:  0.75 sec
# Epoch no. 5 |test accuracy:  74.688 % |total_loss:  4.507118068635464 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  79.688 % |total_loss:  2.1818973533809185 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  78.438 % |total_loss:  1.0572522319853306 | epoch_duration:  0.75 sec
# Epoch no. 8 |test accuracy:  78.125 % |total_loss:  0.5967335132881999 | epoch_duration:  0.8 sec
# Epoch no. 9 |test accuracy:  80.0 % |total_loss:  0.32374973222613335 | epoch_duration:  1.29 sec
# Epoch no. 10 |test accuracy:  81.875 % |total_loss:  0.17760095885023475 | epoch_duration:  1.26 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  42.5 % |total_loss:  96.33709669113159 | epoch_duration:  0.77 sec
# Epoch no. 2 |test accuracy:  68.75 % |total_loss:  31.626525282859802 | epoch_duration:  0.76 sec
# Epoch no. 3 |test accuracy:  75.0 % |total_loss:  13.71670538187027 | epoch_duration:  0.76 sec
# Epoch no. 4 |test accuracy:  74.688 % |total_loss:  6.237429596483707 | epoch_duration:  0.74 sec
# Epoch no. 5 |test accuracy:  75.625 % |total_loss:  3.073597300797701 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  75.312 % |total_loss:  1.5024798661470413 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  77.5 % |total_loss:  0.6172324470244348 | epoch_duration:  0.74 sec
# Epoch no. 8 |test accuracy:  76.25 % |total_loss:  0.24986181780695915 | epoch_duration:  0.75 sec
# Epoch no. 9 |test accuracy:  77.188 % |total_loss:  0.12518197856843472 | epoch_duration:  1.32 sec
# Epoch no. 10 |test accuracy:  76.875 % |total_loss:  0.08536813617683947 | epoch_duration:  1.29 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  44.688 % |total_loss:  94.0345311164856 | epoch_duration:  0.77 sec
# Epoch no. 2 |test accuracy:  71.562 % |total_loss:  31.39621150493622 | epoch_duration:  0.74 sec
# Epoch no. 3 |test accuracy:  82.812 % |total_loss:  13.146026074886322 | epoch_duration:  0.75 sec
# Epoch no. 4 |test accuracy:  80.625 % |total_loss:  5.679163597524166 | epoch_duration:  0.76 sec
# Epoch no. 5 |test accuracy:  80.0 % |total_loss:  2.9825982116162777 | epoch_duration:  0.77 sec
# Epoch no. 6 |test accuracy:  84.688 % |total_loss:  1.8652543500065804 | epoch_duration:  0.77 sec
# Epoch no. 7 |test accuracy:  86.25 % |total_loss:  0.9761379547417164 | epoch_duration:  0.76 sec
# Epoch no. 8 |test accuracy:  85.312 % |total_loss:  0.6295543196611106 | epoch_duration:  0.75 sec
# Epoch no. 9 |test accuracy:  86.25 % |total_loss:  0.4584491269197315 | epoch_duration:  0.75 sec
# Epoch no. 10 |test accuracy:  85.938 % |total_loss:  0.5507274302653968 | epoch_duration:  0.76 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  54.375 % |total_loss:  119.14249992370605 | epoch_duration:  0.76 sec
# Epoch no. 2 |test accuracy:  73.125 % |total_loss:  30.529587388038635 | epoch_duration:  0.77 sec
# Epoch no. 3 |test accuracy:  78.75 % |total_loss:  15.64147999882698 | epoch_duration:  0.76 sec
# Epoch no. 4 |test accuracy:  83.75 % |total_loss:  7.8001944571733475 | epoch_duration:  1.27 sec
# Epoch no. 5 |test accuracy:  86.25 % |total_loss:  3.7264454066753387 | epoch_duration:  1.26 sec
# Epoch no. 6 |test accuracy:  86.25 % |total_loss:  1.6748135145753622 | epoch_duration:  0.76 sec
# Epoch no. 7 |test accuracy:  88.75 % |total_loss:  0.6723330859094858 | epoch_duration:  0.76 sec
# Epoch no. 8 |test accuracy:  89.062 % |total_loss:  0.35889885062351823 | epoch_duration:  0.75 sec
# Epoch no. 9 |test accuracy:  88.438 % |total_loss:  0.23337331553921103 | epoch_duration:  0.75 sec
# Epoch no. 10 |test accuracy:  87.5 % |total_loss:  0.15452192723751068 | epoch_duration:  0.75 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  38.125 % |total_loss:  114.22398245334625 | epoch_duration:  0.74 sec
# Epoch no. 2 |test accuracy:  69.688 % |total_loss:  37.24590319395065 | epoch_duration:  0.73 sec
# Epoch no. 3 |test accuracy:  80.312 % |total_loss:  15.577552676200867 | epoch_duration:  0.75 sec
# Epoch no. 4 |test accuracy:  82.188 % |total_loss:  7.461293175816536 | epoch_duration:  0.75 sec
# Epoch no. 5 |test accuracy:  85.0 % |total_loss:  3.7164263911545277 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  85.0 % |total_loss:  1.9786453023552895 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  84.062 % |total_loss:  0.9119448643177748 | epoch_duration:  0.76 sec
# Epoch no. 8 |test accuracy:  86.25 % |total_loss:  0.6407424006611109 | epoch_duration:  0.74 sec
# Epoch no. 9 |test accuracy:  85.938 % |total_loss:  0.36327170161530375 | epoch_duration:  1.09 sec
# Epoch no. 10 |test accuracy:  86.875 % |total_loss:  0.1653549058828503 | epoch_duration:  1.26 sec
# Number of seed_images = 32
# Epoch no. 1 |test accuracy:  17.5 % |total_loss:  155.0945816040039 | epoch_duration:  0.92 sec
# Epoch no. 2 |test accuracy:  57.188 % |total_loss:  49.776627004146576 | epoch_duration:  0.8 sec
# Epoch no. 3 |test accuracy:  76.25 % |total_loss:  21.210377156734467 | epoch_duration:  0.74 sec
# Epoch no. 4 |test accuracy:  77.812 % |total_loss:  10.52640976011753 | epoch_duration:  0.75 sec
# Epoch no. 5 |test accuracy:  77.812 % |total_loss:  5.815677493810654 | epoch_duration:  0.75 sec
# Epoch no. 6 |test accuracy:  81.875 % |total_loss:  3.7347199954092503 | epoch_duration:  0.75 sec
# Epoch no. 7 |test accuracy:  81.25 % |total_loss:  2.205033991485834 | epoch_duration:  0.77 sec
# Epoch no. 8 |test accuracy:  81.875 % |total_loss:  1.240465230308473 | epoch_duration:  0.8 sec
# Epoch no. 9 |test accuracy:  84.688 % |total_loss:  0.7322159623727202 | epoch_duration:  0.77 sec
# Epoch no. 10 |test accuracy:  83.438 % |total_loss:  0.3374676527455449 | epoch_duration:  0.76 sec

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

epochs = [i for i in range(10)]
 
for i in range(len(k_list)):
  plt.plot(epochs, np.mean(np.asarray(seed_image_experiment_2)[i,:,:], axis=0), label=str(k_list[i]))

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("MNIST - Simple Convnet")
plt.legend(title = 'k')
